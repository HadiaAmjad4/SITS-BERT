# %% [markdown]
# # Pre-Training
# Time2SenCrop

# %%
# Step 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# Step 2: Copy ZIP file from Google Drive to Colab
import shutil

# Replace with your actual ZIP file path if different
zip_path = '/content/drive/MyDrive/TimeSen2Crop.zip'
local_zip_path = '/content/TimeSen2Crop.zip'

shutil.copy(zip_path, local_zip_path)

# %%
# Step 3: Unzip in Colab
import zipfile

with zipfile.ZipFile(local_zip_path, 'r') as zip_ref:
    zip_ref.extractall('/content/TimeSen2Crop')

# %%
# Step 4: Set up and import libraries
import pandas as pd
import numpy as np
import os
from tqdm import tqdm

# %%
# Step 5: Set path to the area you want to process
area_path = '/content/TimeSen2Crop/TimeSen2Crop/32TPT'
dates_file = os.path.join(area_path, 'dates.csv')

# Load Julian dates
dates_file = os.path.join(area_path, 'dates.csv')
julian_dates = pd.read_csv(dates_file, skiprows=1, header=None).squeeze().tolist()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-a783fc66c649> in <cell line: 0>()
#       5 # Load Julian dates
#       6 dates_file = os.path.join(area_path, 'dates.csv')
# ----> 7 julian_dates = pd.read_csv(dates_file, skiprows=1, header=None).squeeze().tolist()
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/TimeSen2Crop/TimeSen2Crop/32TPT/dates.csv'

# %%
print(julian_dates[:5])
# Out:
# [20170904, 20171014, 20171019, 20171024, 20171103]

# %%
from datetime import datetime

def convert_to_doy(date_int):
    date_str = str(date_int)
    date_obj = datetime.strptime(date_str, '%Y%m%d')
    return date_obj.timetuple().tm_yday

output_rows = []

for class_id in range(16):
    class_folder = os.path.join(area_path, str(class_id))
    print(f"🔍 Checking class folder: {class_folder}")

    if not os.path.exists(class_folder):
        print(f"❌ Folder not found: {class_folder}")
        continue

    pixel_csvs = [f for f in os.listdir(class_folder) if f.endswith('.csv')]
    print(f"📂 Found {len(pixel_csvs)} CSVs in class {class_id}")

    for csv_file in tqdm(pixel_csvs, desc=f"Processing class {class_id}"):
        pixel_path = os.path.join(class_folder, csv_file)

        try:
            df = pd.read_csv(pixel_path)
        except Exception as e:
            print(f"⚠️ Error reading {csv_file}: {e}")
            continue

        # ✅ Check for exactly 10 columns: 9 bands + flag
        if df.shape[1] != 10:
            print(f"⚠️ Skipping {csv_file}: Expected 10 columns, got {df.shape}")
            continue

        if df.shape[0] == 0:
            print(f"⚠️ Skipping {csv_file}: No data rows")
            continue

        N = df.shape[0]  # number of time steps

        # Flatten all 10 columns (including flag) column-wise
        flat_values = []
        for col in df.columns:
            flat_values.extend(df[col].tolist())

        # Add first N Julian dates converted to day-of-year
        if N > len(julian_dates):
            print(f"⚠️ Skipping {csv_file}: Not enough Julian dates for {N} time steps")
            continue

        raw_dates = julian_dates[:N]
        # Convert each date to day-of-year integer
        doy_dates = [convert_to_doy(int(d)) for d in raw_dates]

        # Combine everything
        row = flat_values + doy_dates
        output_rows.append(row)

# Save the final CSV
output_df = pd.DataFrame(output_rows)
output_path = '/content/drive/MyDrive/processed_32TPT.csv'
output_df.to_csv(output_path, index=False, header=False)

print(f"✅ Final CSV saved to: {output_path}")
print(f"📈 Total rows written: {len(output_df)}")
# Out:
# 🔍 Checking class folder: /content/TimeSen2Crop/TimeSen2Crop/32TPT/0
# 📂 Found 1 CSVs in class 0
# Processing class 0: 100%|██████████| 1/1 [00:00<00:00, 207.25it/s]
# 🔍 Checking class folder: /content/TimeSen2Crop/TimeSen2Crop/32TPT/1
# 📂 Found 20001 CSVs in class 1
# Processing class 1: 100%|██████████| 20001/20001 [00:40<00:00, 497.30it/s]
# 🔍 Checking class folder: /content/TimeSen2Crop/TimeSen2Crop/32TPT/2
# 📂 Found 1684 CSVs in class 2
# Processing class 2: 100%|██████████| 1684/1684 [00:11<00:00, 149.71it/s]
# 🔍 Checking class folder: /content/TimeSen2Crop/TimeSen2Crop/32TPT/3
# 📂 Found 458 CSVs in class 3
# Processing class 3: 100%|██████████| 458/458 [00:01<00:00, 390.86it/s]
# 🔍 Checking class folder: /content/TimeSen2Crop/TimeSen2Crop/32TPT/4
# 📂 Found 0 CSVs in class 4
# Processing class 4: 0it [00:00, ?it/s]
# 🔍 Checking class folder: /content/TimeSen2Crop/TimeSen2Crop/32TPT/5
# 📂 Found 0 CSVs in class 5
# Processing class 5: 0it [00:00, ?it/s]
# 🔍 Checking class folder: /content/TimeSen2Crop/TimeSen2Crop/32TPT/6
# 📂 Found 33 CSVs in class 6
# Processing class 6: 100%|██████████| 33/33 [00:00<00:00, 549.81it/s]
# 🔍 Checking class folder: /content/TimeSen2Crop/TimeSen2Crop/32TPT/7
# 📂 Found 0 CSVs in class 7
# Processing class 7: 0it [00:00, ?it/s]
# 🔍 Checking class folder: /content/TimeSen2Crop/TimeSen2Crop/32TPT/8
# 📂 Found 52 CSVs in class 8
# Processing class 8: 100%|██████████| 52/52 [00:00<00:00, 532.98it/s]
# 🔍 Checking class folder: /content/TimeSen2Crop/TimeSen2Crop/32TPT/9
# 📂 Found 0 CSVs in class 9
# Processing class 9: 0it [00:00, ?it/s]
# 🔍 Checking class folder: /content/TimeSen2Crop/TimeSen2Crop/32TPT/10
# 📂 Found 7 CSVs in class 10
# Processing class 10: 100%|██████████| 7/7 [00:00<00:00, 429.51it/s]
# 🔍 Checking class folder: /content/TimeSen2Crop/TimeSen2Crop/32TPT/11
# 📂 Found 229 CSVs in class 11
# Processing class 11: 100%|██████████| 229/229 [00:00<00:00, 526.57it/s]
# 🔍 Checking class folder: /content/TimeSen2Crop/TimeSen2Crop/32TPT/12
# 📂 Found 47 CSVs in class 12
# Processing class 12: 100%|██████████| 47/47 [00:00<00:00, 574.85it/s]
# 🔍 Checking class folder: /content/TimeSen2Crop/TimeSen2Crop/32TPT/13
# 📂 Found 82 CSVs in class 13
# Processing class 13: 100%|██████████| 82/82 [00:00<00:00, 543.60it/s]
# 🔍 Checking class folder: /content/TimeSen2Crop/TimeSen2Crop/32TPT/14
# 📂 Found 97 CSVs in class 14
# Processing class 14: 100%|██████████| 97/97 [00:00<00:00, 565.71it/s]
# 🔍 Checking class folder: /content/TimeSen2Crop/TimeSen2Crop/32TPT/15
# 📂 Found 1841 CSVs in class 15
# Processing class 15: 100%|██████████| 1841/1841 [00:03<00:00, 536.74it/s]
# ✅ Final CSV saved to: /content/drive/MyDrive/processed_32TPT.csv
# 📈 Total rows written: 24532

# %%
# !git clone https://github.com/linlei1214/SITS-BERT.git
# Out:
# Cloning into 'SITS-BERT'...
# remote: Enumerating objects: 153, done.
# remote: Counting objects: 100% (153/153), done.
# remote: Compressing objects: 100% (137/137), done.
# remote: Total 153 (delta 24), reused 118 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (153/153), 8.70 MiB | 15.97 MiB/s, done.
# Resolving deltas: 100% (24/24), done.

# %%
# !python /content/SITS-BERT/code/pretraining.py \
    --dataset_path '/content/drive/MyDrive/processed_32TPT.csv' \
    --pretrain_path '/content/drive/MyDrive/checkpoints/pretrain/' \
    --valid_rate 0.03 \
    --max_length 64 \
    --num_features 10 \
    --epochs 100 \
    --batch_size 256 \
    --hidden_size 256 \
    --layers 3 \
    --attn_heads 8 \
    --learning_rate 1e-4 \
    --warmup_epochs 10 \
    --decay_gamma 0.99 \
    --dropout 0.1 \
    --gradient_clipping 5.0
# Out:
# 2025-05-18 09:36:44.266441: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747561004.299580    3569 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747561004.306157    3569 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-18 09:36:44.326297: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading training and validation data sets...
# loading data successful
# training samples: 23797, validation samples: 735
# Initialing SITS-BERT...
# Total Parameters: 2373258
# Pre-training SITS-BERT...
# EP_train:0:   0% 0/46 [00:00<?, ?it/s]/content/SITS-BERT/code/trainer/pretrain.py:66: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   nn.utils.clip_grad_norm(self.model.parameters(), self.gradient_clippling)
# {'epoch': 0, 'iter': 0, 'avg_loss': 4.653506755828857, 'loss': 4.653506755828857}
# {'epoch': 0, 'iter': 10, 'avg_loss': 2.2202975749969482, 'loss': 1.2875962257385254}
# {'epoch': 0, 'iter': 20, 'avg_loss': 1.6278045716739835, 'loss': 0.7653279900550842}
# {'epoch': 0, 'iter': 30, 'avg_loss': 1.3184201352057918, 'loss': 0.5914866924285889}
# {'epoch': 0, 'iter': 40, 'avg_loss': 1.126300812494464, 'loss': 0.4804222881793976}
# EP_train:0: 100% 46/46 [00:24<00:00,  1.89it/s]
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:819: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   _warn_get_lr_called_within_step(self)
# EP0, train_loss=1.05388, validate_loss=0.15217
# EP:0 Model Saved on: /content/drive/MyDrive/checkpoints/pretraincheckpoint.tar
# {'epoch': 1, 'iter': 0, 'avg_loss': 0.42945826053619385, 'loss': 0.42945826053619385}
# {'epoch': 1, 'iter': 10, 'avg_loss': 0.4060227058150552, 'loss': 0.3833629786968231}
# {'epoch': 1, 'iter': 20, 'avg_loss': 0.388175429332824, 'loss': 0.3580515384674072}
# {'epoch': 1, 'iter': 30, 'avg_loss': 0.3724941784335721, 'loss': 0.3282216191291809}
# {'epoch': 1, 'iter': 40, 'avg_loss': 0.35979139514085723, 'loss': 0.3029174208641052}
# EP_train:1: 100% 46/46 [00:25<00:00,  1.79it/s]
# EP1, train_loss=0.35380, validate_loss=0.13189
# EP:1 Model Saved on: /content/drive/MyDrive/checkpoints/pretraincheckpoint.tar
# {'epoch': 2, 'iter': 0, 'avg_loss': 0.2989712953567505, 'loss': 0.2989712953567505}
# {'epoch': 2, 'iter': 10, 'avg_loss': 0.2914983034133911, 'loss': 0.2817147672176361}
# {'epoch': 2, 'iter': 20, 'avg_loss': 0.28548488446644377, 'loss': 0.27410516142845154}
# {'epoch': 2, 'iter': 30, 'avg_loss': 0.2803798442886722, 'loss': 0.2668919861316681}
# {'epoch': 2, 'iter': 40, 'avg_loss': 0.27418752378079947, 'loss': 0.2570236027240753}
# EP_train:2: 100% 46/46 [00:24<00:00,  1.90it/s]
# EP2, train_loss=0.27150, validate_loss=0.13148
# EP:2 Model Saved on: /content/drive/MyDrive/checkpoints/pretraincheckpoint.tar
# {'epoch': 3, 'iter': 0, 'avg_loss': 0.23884287476539612, 'loss': 0.23884287476539612}
# {'epoch': 3, 'iter': 10, 'avg_loss': 0.243600456552072, 'loss': 0.23583896458148956}
# {'epoch': 3, 'iter': 20, 'avg_loss': 0.23941684336889357, 'loss': 0.23218698799610138}
# {'epoch': 3, 'iter': 30, 'avg_loss': 0.23674167836866072, 'loss': 0.22631309926509857}
# {'epoch': 3, 'iter': 40, 'avg_loss': 0.23461020101861255, 'loss': 0.22927822172641754}
# EP_train:3: 100% 46/46 [00:24<00:00,  1.88it/s]
# EP3, train_loss=0.23296, validate_loss=0.13560
# {'epoch': 4, 'iter': 0, 'avg_loss': 0.22084887325763702, 'loss': 0.22084887325763702}
# {'epoch': 4, 'iter': 10, 'avg_loss': 0.21706435897133566, 'loss': 0.2124759554862976}
# {'epoch': 4, 'iter': 20, 'avg_loss': 0.21441069954917544, 'loss': 0.2044442743062973}
# {'epoch': 4, 'iter': 30, 'avg_loss': 0.21153213179880573, 'loss': 0.2096758633852005}
# {'epoch': 4, 'iter': 40, 'avg_loss': 0.2095083830560126, 'loss': 0.19494688510894775}
# EP_train:4: 100% 46/46 [00:24<00:00,  1.88it/s]
# EP4, train_loss=0.20833, validate_loss=0.14219
# {'epoch': 5, 'iter': 0, 'avg_loss': 0.19811797142028809, 'loss': 0.19811797142028809}
# {'epoch': 5, 'iter': 10, 'avg_loss': 0.19608459824865515, 'loss': 0.1990010291337967}
# {'epoch': 5, 'iter': 20, 'avg_loss': 0.19418851321651823, 'loss': 0.19705846905708313}
# {'epoch': 5, 'iter': 30, 'avg_loss': 0.19310234246715421, 'loss': 0.18950387835502625}
# {'epoch': 5, 'iter': 40, 'avg_loss': 0.19082712763693274, 'loss': 0.18260568380355835}
# EP_train:5: 100% 46/46 [00:24<00:00,  1.89it/s]
# EP5, train_loss=0.19020, validate_loss=0.12784
# EP:5 Model Saved on: /content/drive/MyDrive/checkpoints/pretraincheckpoint.tar
# {'epoch': 6, 'iter': 0, 'avg_loss': 0.18980152904987335, 'loss': 0.18980152904987335}
# {'epoch': 6, 'iter': 10, 'avg_loss': 0.18357531184499915, 'loss': 0.1819474846124649}
# {'epoch': 6, 'iter': 20, 'avg_loss': 0.18105638452938624, 'loss': 0.1742689162492752}
# {'epoch': 6, 'iter': 30, 'avg_loss': 0.17869819268103568, 'loss': 0.17263570427894592}
# {'epoch': 6, 'iter': 40, 'avg_loss': 0.17775212228298187, 'loss': 0.1771799921989441}
# EP_train:6: 100% 46/46 [00:24<00:00,  1.89it/s]
# EP6, train_loss=0.17715, validate_loss=0.13511
# {'epoch': 7, 'iter': 0, 'avg_loss': 0.16832242906093597, 'loss': 0.16832242906093597}
# {'epoch': 7, 'iter': 10, 'avg_loss': 0.16959077390757474, 'loss': 0.16743066906929016}
# {'epoch': 7, 'iter': 20, 'avg_loss': 0.16915195399806612, 'loss': 0.16718730330467224}
# {'epoch': 7, 'iter': 30, 'avg_loss': 0.16880325732692594, 'loss': 0.1656719446182251}
# {'epoch': 7, 'iter': 40, 'avg_loss': 0.16744998642584172, 'loss': 0.16240672767162323}
# EP_train:7: 100% 46/46 [00:24<00:00,  1.88it/s]
# EP7, train_loss=0.16712, validate_loss=0.13091
# {'epoch': 8, 'iter': 0, 'avg_loss': 0.15742412209510803, 'loss': 0.15742412209510803}
# {'epoch': 8, 'iter': 10, 'avg_loss': 0.16158562492240558, 'loss': 0.16424895823001862}
# {'epoch': 8, 'iter': 20, 'avg_loss': 0.16139512189796992, 'loss': 0.15706375241279602}
# {'epoch': 8, 'iter': 30, 'avg_loss': 0.1605666010610519, 'loss': 0.15874582529067993}
# {'epoch': 8, 'iter': 40, 'avg_loss': 0.159780856676218, 'loss': 0.16109947860240936}
# EP_train:8: 100% 46/46 [00:24<00:00,  1.89it/s]
# EP8, train_loss=0.15931, validate_loss=0.11946
# EP:8 Model Saved on: /content/drive/MyDrive/checkpoints/pretraincheckpoint.tar
# {'epoch': 9, 'iter': 0, 'avg_loss': 0.15105296671390533, 'loss': 0.15105296671390533}
# {'epoch': 9, 'iter': 10, 'avg_loss': 0.15164346315644003, 'loss': 0.1474894881248474}
# {'epoch': 9, 'iter': 20, 'avg_loss': 0.15197449638730004, 'loss': 0.14827047288417816}
# {'epoch': 9, 'iter': 30, 'avg_loss': 0.1511611823112734, 'loss': 0.15147444605827332}
# {'epoch': 9, 'iter': 40, 'avg_loss': 0.1504035762897352, 'loss': 0.14483635127544403}
# EP_train:9: 100% 46/46 [00:24<00:00,  1.89it/s]
# EP9, train_loss=0.15006, validate_loss=0.12287
# {'epoch': 10, 'iter': 0, 'avg_loss': 0.14943096041679382, 'loss': 0.14943096041679382}
# {'epoch': 10, 'iter': 10, 'avg_loss': 0.14652752469886432, 'loss': 0.14659756422042847}
# {'epoch': 10, 'iter': 20, 'avg_loss': 0.14527571272282375, 'loss': 0.14548516273498535}
# {'epoch': 10, 'iter': 30, 'avg_loss': 0.14462479179905308, 'loss': 0.14058318734169006}
# {'epoch': 10, 'iter': 40, 'avg_loss': 0.14407803009196027, 'loss': 0.14011064171791077}
# EP_train:10: 100% 46/46 [00:24<00:00,  1.87it/s]
# EP10, train_loss=0.14405, validate_loss=0.11506
# EP:10 Model Saved on: /content/drive/MyDrive/checkpoints/pretraincheckpoint.tar
# {'epoch': 11, 'iter': 0, 'avg_loss': 0.13779179751873016, 'loss': 0.13779179751873016}
# {'epoch': 11, 'iter': 10, 'avg_loss': 0.13899889046495612, 'loss': 0.1460605412721634}
# {'epoch': 11, 'iter': 20, 'avg_loss': 0.1390145087525958, 'loss': 0.13442178070545197}
# {'epoch': 11, 'iter': 30, 'avg_loss': 0.13869186034125666, 'loss': 0.1395474225282669}
# {'epoch': 11, 'iter': 40, 'avg_loss': 0.1380087904086927, 'loss': 0.13810665905475616}
# EP_train:11: 100% 46/46 [00:24<00:00,  1.89it/s]
# EP11, train_loss=0.13762, validate_loss=0.11802
# {'epoch': 12, 'iter': 0, 'avg_loss': 0.1327735334634781, 'loss': 0.1327735334634781}
# {'epoch': 12, 'iter': 10, 'avg_loss': 0.1341810795393857, 'loss': 0.14174911379814148}
# {'epoch': 12, 'iter': 20, 'avg_loss': 0.13380824739024752, 'loss': 0.13346780836582184}
# {'epoch': 12, 'iter': 30, 'avg_loss': 0.13351188888472895, 'loss': 0.13454250991344452}
# {'epoch': 12, 'iter': 40, 'avg_loss': 0.13285645442764935, 'loss': 0.13041377067565918}
# EP_train:12: 100% 46/46 [00:24<00:00,  1.91it/s]
# EP12, train_loss=0.13265, validate_loss=0.12068
# {'epoch': 13, 'iter': 0, 'avg_loss': 0.12679703533649445, 'loss': 0.12679703533649445}
# {'epoch': 13, 'iter': 10, 'avg_loss': 0.1292468641291965, 'loss': 0.12971393764019012}
# {'epoch': 13, 'iter': 20, 'avg_loss': 0.12785370151201883, 'loss': 0.1256444901227951}
# {'epoch': 13, 'iter': 30, 'avg_loss': 0.12766468404762207, 'loss': 0.12773331999778748}
# {'epoch': 13, 'iter': 40, 'avg_loss': 0.1272518095083353, 'loss': 0.12122756987810135}
# EP_train:13: 100% 46/46 [00:24<00:00,  1.87it/s]
# EP13, train_loss=0.12695, validate_loss=0.11664
# {'epoch': 14, 'iter': 0, 'avg_loss': 0.12021127343177795, 'loss': 0.12021127343177795}
# {'epoch': 14, 'iter': 10, 'avg_loss': 0.12187812477350235, 'loss': 0.12368316948413849}
# {'epoch': 14, 'iter': 20, 'avg_loss': 0.12170437404087611, 'loss': 0.12033214420080185}
# {'epoch': 14, 'iter': 30, 'avg_loss': 0.12075005399603997, 'loss': 0.119535431265831}
# {'epoch': 14, 'iter': 40, 'avg_loss': 0.11996728236355432, 'loss': 0.11087042838335037}
# EP_train:14: 100% 46/46 [00:24<00:00,  1.90it/s]
# EP14, train_loss=0.11940, validate_loss=0.11061
# EP:14 Model Saved on: /content/drive/MyDrive/checkpoints/pretraincheckpoint.tar
# {'epoch': 15, 'iter': 0, 'avg_loss': 0.11645111441612244, 'loss': 0.11645111441612244}
# {'epoch': 15, 'iter': 10, 'avg_loss': 0.11601075733249838, 'loss': 0.11273295432329178}
# {'epoch': 15, 'iter': 20, 'avg_loss': 0.11583567978370757, 'loss': 0.1159975528717041}
# {'epoch': 15, 'iter': 30, 'avg_loss': 0.11515081818065336, 'loss': 0.11412902176380157}
# {'epoch': 15, 'iter': 40, 'avg_loss': 0.11403175588788056, 'loss': 0.1149505153298378}
# EP_train:15: 100% 46/46 [00:24<00:00,  1.89it/s]
# EP15, train_loss=0.11340, validate_loss=0.09256
# EP:15 Model Saved on: /content/drive/MyDrive/checkpoints/pretraincheckpoint.tar
# {'epoch': 16, 'iter': 0, 'avg_loss': 0.11320753395557404, 'loss': 0.11320753395557404}
# {'epoch': 16, 'iter': 10, 'avg_loss': 0.11065188388932835, 'loss': 0.1127815768122673}
# {'epoch': 16, 'iter': 20, 'avg_loss': 0.11017170725833803, 'loss': 0.11168631166219711}
# {'epoch': 16, 'iter': 30, 'avg_loss': 0.10895170728045125, 'loss': 0.10936898738145828}
# {'epoch': 16, 'iter': 40, 'avg_loss': 0.10797124101621348, 'loss': 0.10358718037605286}
# EP_train:16: 100% 46/46 [00:24<00:00,  1.86it/s]
# EP16, train_loss=0.10738, validate_loss=0.09363
# {'epoch': 17, 'iter': 0, 'avg_loss': 0.10612951964139938, 'loss': 0.10612951964139938}
# {'epoch': 17, 'iter': 10, 'avg_loss': 0.10309433192014694, 'loss': 0.10098430514335632}
# {'epoch': 17, 'iter': 20, 'avg_loss': 0.10261791305882591, 'loss': 0.10016168653964996}
# {'epoch': 17, 'iter': 30, 'avg_loss': 0.10192266274844447, 'loss': 0.09816618263721466}
# {'epoch': 17, 'iter': 40, 'avg_loss': 0.10123857910313257, 'loss': 0.09996584802865982}
# EP_train:17: 100% 46/46 [00:24<00:00,  1.88it/s]
# EP17, train_loss=0.10109, validate_loss=0.09038
# EP:17 Model Saved on: /content/drive/MyDrive/checkpoints/pretraincheckpoint.tar
# {'epoch': 18, 'iter': 0, 'avg_loss': 0.09952108561992645, 'loss': 0.09952108561992645}
# {'epoch': 18, 'iter': 10, 'avg_loss': 0.09661831571297212, 'loss': 0.0931474044919014}
# {'epoch': 18, 'iter': 20, 'avg_loss': 0.09682087635710127, 'loss': 0.09480872750282288}
# {'epoch': 18, 'iter': 30, 'avg_loss': 0.09679918351673311, 'loss': 0.09690289944410324}
# {'epoch': 18, 'iter': 40, 'avg_loss': 0.09670568966284031, 'loss': 0.09482161700725555}
# EP_train:18: 100% 46/46 [00:24<00:00,  1.89it/s]
# EP18, train_loss=0.09652, validate_loss=0.07523
# EP:18 Model Saved on: /content/drive/MyDrive/checkpoints/pretraincheckpoint.tar
# {'epoch': 19, 'iter': 0, 'avg_loss': 0.09431793540716171, 'loss': 0.09431793540716171}
# {'epoch': 19, 'iter': 10, 'avg_loss': 0.09297525340860541, 'loss': 0.09313782304525375}
# {'epoch': 19, 'iter': 20, 'avg_loss': 0.09219626869474139, 'loss': 0.09222481399774551}
# {'epoch': 19, 'iter': 30, 'avg_loss': 0.09225826686428439, 'loss': 0.09267069399356842}
# {'epoch': 19, 'iter': 40, 'avg_loss': 0.09204539856532724, 'loss': 0.0936572477221489}
# EP_train:19: 100% 46/46 [00:25<00:00,  1.84it/s]
# EP19, train_loss=0.09181, validate_loss=0.07651
# {'epoch': 20, 'iter': 0, 'avg_loss': 0.08853417634963989, 'loss': 0.08853417634963989}
# {'epoch': 20, 'iter': 10, 'avg_loss': 0.08858465403318405, 'loss': 0.08722519874572754}
# {'epoch': 20, 'iter': 20, 'avg_loss': 0.08904260113125756, 'loss': 0.09076462686061859}
# {'epoch': 20, 'iter': 30, 'avg_loss': 0.08888346413450857, 'loss': 0.08613529801368713}
# {'epoch': 20, 'iter': 40, 'avg_loss': 0.08858683123821165, 'loss': 0.0887213870882988}
# EP_train:20: 100% 46/46 [00:24<00:00,  1.90it/s]
# EP20, train_loss=0.08853, validate_loss=0.06869
# EP:20 Model Saved on: /content/drive/MyDrive/checkpoints/pretraincheckpoint.tar
# {'epoch': 21, 'iter': 0, 'avg_loss': 0.08794194459915161, 'loss': 0.08794194459915161}
# {'epoch': 21, 'iter': 10, 'avg_loss': 0.08622730794278058, 'loss': 0.08944954723119736}
# {'epoch': 21, 'iter': 20, 'avg_loss': 0.0865302277462823, 'loss': 0.08385796844959259}
# {'epoch': 21, 'iter': 30, 'avg_loss': 0.08620932938591126, 'loss': 0.08565416932106018}
# {'epoch': 21, 'iter': 40, 'avg_loss': 0.08613286803408367, 'loss': 0.08602143824100494}
# EP_train:21: 100% 46/46 [00:24<00:00,  1.88it/s]
# EP21, train_loss=0.08590, validate_loss=0.07012
# {'epoch': 22, 'iter': 0, 'avg_loss': 0.08756249397993088, 'loss': 0.08756249397993088}
# {'epoch': 22, 'iter': 10, 'avg_loss': 0.08617230233821002, 'loss': 0.08118482679128647}
# {'epoch': 22, 'iter': 20, 'avg_loss': 0.08612431834141414, 'loss': 0.0858096331357956}
# {'epoch': 22, 'iter': 30, 'avg_loss': 0.08508880003806084, 'loss': 0.08614752441644669}
# {'epoch': 22, 'iter': 40, 'avg_loss': 0.08489105141744381, 'loss': 0.08402881771326065}
# EP_train:22: 100% 46/46 [00:24<00:00,  1.89it/s]
# EP22, train_loss=0.08449, validate_loss=0.05956
# EP:22 Model Saved on: /content/drive/MyDrive/checkpoints/pretraincheckpoint.tar
# {'epoch': 23, 'iter': 0, 'avg_loss': 0.08072550594806671, 'loss': 0.08072550594806671}
# {'epoch': 23, 'iter': 10, 'avg_loss': 0.08093334192579443, 'loss': 0.08180040121078491}
# {'epoch': 23, 'iter': 20, 'avg_loss': 0.08059140046437581, 'loss': 0.0834435448050499}
# {'epoch': 23, 'iter': 30, 'avg_loss': 0.08037242966313515, 'loss': 0.08276452869176865}
# {'epoch': 23, 'iter': 40, 'avg_loss': 0.0801503829112867, 'loss': 0.07743684947490692}
# EP_train:23: 100% 46/46 [00:24<00:00,  1.86it/s]
# EP23, train_loss=0.07987, validate_loss=0.06138
# {'epoch': 24, 'iter': 0, 'avg_loss': 0.07902784645557404, 'loss': 0.07902784645557404}
# {'epoch': 24, 'iter': 10, 'avg_loss': 0.0788979090072892, 'loss': 0.07985053956508636}
# {'epoch': 24, 'iter': 20, 'avg_loss': 0.07812410309201195, 'loss': 0.07806850969791412}
# {'epoch': 24, 'iter': 30, 'avg_loss': 0.0781133696436882, 'loss': 0.08210153132677078}
# {'epoch': 24, 'iter': 40, 'avg_loss': 0.07737568947600156, 'loss': 0.07353094220161438}
# EP_train:24: 100% 46/46 [00:24<00:00,  1.90it/s]
# EP24, train_loss=0.07709, validate_loss=0.06000
# {'epoch': 25, 'iter': 0, 'avg_loss': 0.07837818562984467, 'loss': 0.07837818562984467}
# {'epoch': 25, 'iter': 10, 'avg_loss': 0.07643150470473549, 'loss': 0.07531293481588364}
# {'epoch': 25, 'iter': 20, 'avg_loss': 0.0756864437744731, 'loss': 0.0736473947763443}
# {'epoch': 25, 'iter': 30, 'avg_loss': 0.07520390085635646, 'loss': 0.07444507628679276}
# {'epoch': 25, 'iter': 40, 'avg_loss': 0.07503067120546247, 'loss': 0.07585296779870987}
# EP_train:25: 100% 46/46 [00:24<00:00,  1.90it/s]
# EP25, train_loss=0.07484, validate_loss=0.05852
# EP:25 Model Saved on: /content/drive/MyDrive/checkpoints/pretraincheckpoint.tar
# {'epoch': 26, 'iter': 0, 'avg_loss': 0.07362934201955795, 'loss': 0.07362934201955795}
# {'epoch': 26, 'iter': 10, 'avg_loss': 0.07361189275979996, 'loss': 0.0722212940454483}
# {'epoch': 26, 'iter': 20, 'avg_loss': 0.07319051311129615, 'loss': 0.07262378185987473}
# {'epoch': 26, 'iter': 30, 'avg_loss': 0.07325561777237923, 'loss': 0.0725376233458519}
# {'epoch': 26, 'iter': 40, 'avg_loss': 0.07306596527739269, 'loss': 0.07414030283689499}
# EP_train:26: 100% 46/46 [00:24<00:00,  1.86it/s]
# EP26, train_loss=0.07292, validate_loss=0.05281
# EP:26 Model Saved on: /content/drive/MyDrive/checkpoints/pretraincheckpoint.tar
# {'epoch': 27, 'iter': 0, 'avg_loss': 0.06940683722496033, 'loss': 0.06940683722496033}
# {'epoch': 27, 'iter': 10, 'avg_loss': 0.07148576324636285, 'loss': 0.06846795231103897}
# {'epoch': 27, 'iter': 20, 'avg_loss': 0.07124586403369904, 'loss': 0.07157222926616669}
# {'epoch': 27, 'iter': 30, 'avg_loss': 0.07078385040644676, 'loss': 0.0699813961982727}
# {'epoch': 27, 'iter': 40, 'avg_loss': 0.07035240349246234, 'loss': 0.07134666293859482}
# EP_train:27: 100% 46/46 [00:24<00:00,  1.88it/s]
# EP27, train_loss=0.07027, validate_loss=0.05157
# EP:27 Model Saved on: /content/drive/MyDrive/checkpoints/pretraincheckpoint.tar
# {'epoch': 28, 'iter': 0, 'avg_loss': 0.06798802316188812, 'loss': 0.06798802316188812}
# {'epoch': 28, 'iter': 10, 'avg_loss': 0.06821625273336064, 'loss': 0.06687194854021072}
# {'epoch': 28, 'iter': 20, 'avg_loss': 0.06778874070871443, 'loss': 0.0678597092628479}
# {'epoch': 28, 'iter': 30, 'avg_loss': 0.06799631013024238, 'loss': 0.06954029947519302}
# {'epoch': 28, 'iter': 40, 'avg_loss': 0.0681039002246973, 'loss': 0.06875881552696228}
# EP_train:28: 100% 46/46 [00:24<00:00,  1.86it/s]
# EP28, train_loss=0.06803, validate_loss=0.04857
# EP:28 Model Saved on: /content/drive/MyDrive/checkpoints/pretraincheckpoint.tar
# {'epoch': 29, 'iter': 0, 'avg_loss': 0.06744623929262161, 'loss': 0.06744623929262161}
# {'epoch': 29, 'iter': 10, 'avg_loss': 0.06671362437985161, 'loss': 0.06355943530797958}
# {'epoch': 29, 'iter': 20, 'avg_loss': 0.06692810675927571, 'loss': 0.06793344765901566}
# {'epoch': 29, 'iter': 30, 'avg_loss': 0.06635881792153081, 'loss': 0.06285643577575684}
# {'epoch': 29, 'iter': 40, 'avg_loss': 0.06647968419441362, 'loss': 0.06584610044956207}
# EP_train:29: 100% 46/46 [00:24<00:00,  1.89it/s]
# EP29, train_loss=0.06644, validate_loss=0.05169
# {'epoch': 30, 'iter': 0, 'avg_loss': 0.06580942869186401, 'loss': 0.06580942869186401}
# {'epoch': 30, 'iter': 10, 'avg_loss': 0.06633356890895149, 'loss': 0.06790219992399216}
# {'epoch': 30, 'iter': 20, 'avg_loss': 0.06583224840107418, 'loss': 0.06688845902681351}
# {'epoch': 30, 'iter': 30, 'avg_loss': 0.06574363670041485, 'loss': 0.0662238597869873}
# {'epoch': 30, 'iter': 40, 'avg_loss': 0.06548883311632203, 'loss': 0.06261023133993149}
# EP_train:30: 100% 46/46 [00:24<00:00,  1.89it/s]
# EP30, train_loss=0.06536, validate_loss=0.04901
# {'epoch': 31, 'iter': 0, 'avg_loss': 0.06111864745616913, 'loss': 0.06111864745616913}
# {'epoch': 31, 'iter': 10, 'avg_loss': 0.06408431855115024, 'loss': 0.06619665026664734}
# {'epoch': 31, 'iter': 20, 'avg_loss': 0.06400808762936365, 'loss': 0.0666927918791771}
# {'epoch': 31, 'iter': 30, 'avg_loss': 0.06381412811817662, 'loss': 0.06512626260519028}
# {'epoch': 31, 'iter': 40, 'avg_loss': 0.06380604943487703, 'loss': 0.06742842495441437}
# EP_train:31: 100% 46/46 [00:24<00:00,  1.89it/s]
# EP31, train_loss=0.06372, validate_loss=0.04632
# EP:31 Model Saved on: /content/drive/MyDrive/checkpoints/pretraincheckpoint.tar
# {'epoch': 32, 'iter': 0, 'avg_loss': 0.06412899494171143, 'loss': 0.06412899494171143}
# {'epoch': 32, 'iter': 10, 'avg_loss': 0.06280213729901747, 'loss': 0.060459766536951065}
# {'epoch': 32, 'iter': 20, 'avg_loss': 0.06300060060762223, 'loss': 0.060450371354818344}
# {'epoch': 32, 'iter': 30, 'avg_loss': 0.06259229094270737, 'loss': 0.05976830795407295}
# {'epoch': 32, 'iter': 40, 'avg_loss': 0.062346540118862946, 'loss': 0.06150789186358452}
# EP_train:32: 100% 46/46 [00:24<00:00,  1.89it/s]
# EP32, train_loss=0.06219, validate_loss=0.04524
# EP:32 Model Saved on: /content/drive/MyDrive/checkpoints/pretraincheckpoint.tar
# {'epoch': 33, 'iter': 0, 'avg_loss': 0.061999816447496414, 'loss': 0.061999816447496414}
# {'epoch': 33, 'iter': 10, 'avg_loss': 0.061664087189869446, 'loss': 0.06120705604553223}
# {'epoch': 33, 'iter': 20, 'avg_loss': 0.06122318158547083, 'loss': 0.06103433668613434}
# {'epoch': 33, 'iter': 30, 'avg_loss': 0.06111843475411015, 'loss': 0.059559646993875504}
# {'epoch': 33, 'iter': 40, 'avg_loss': 0.061123413556232686, 'loss': 0.06015933305025101}
# EP_train:33: 100% 46/46 [00:24<00:00,  1.85it/s]
# EP33, train_loss=0.06105, validate_loss=0.04423
# EP:33 Model Saved on: /content/drive/MyDrive/checkpoints/pretraincheckpoint.tar
# {'epoch': 34, 'iter': 0, 'avg_loss': 0.05867829546332359, 'loss': 0.05867829546332359}
# {'epoch': 34, 'iter': 10, 'avg_loss': 0.05984585393558849, 'loss': 0.059011586010456085}
# {'epoch': 34, 'iter': 20, 'avg_loss': 0.0596015639603138, 'loss': 0.057457830756902695}
# {'epoch': 34, 'iter': 30, 'avg_loss': 0.05975876448135222, 'loss': 0.059641141444444656}
# {'epoch': 34, 'iter': 40, 'avg_loss': 0.05967569941791093, 'loss': 0.05956865847110748}
# EP_train:34: 100% 46/46 [00:24<00:00,  1.89it/s]
# EP34, train_loss=0.05976, validate_loss=0.04651
# {'epoch': 35, 'iter': 0, 'avg_loss': 0.05740945413708687, 'loss': 0.05740945413708687}
# {'epoch': 35, 'iter': 10, 'avg_loss': 0.059218409725210884, 'loss': 0.05820233374834061}
# {'epoch': 35, 'iter': 20, 'avg_loss': 0.0589119933900379, 'loss': 0.0600716806948185}
# {'epoch': 35, 'iter': 30, 'avg_loss': 0.058800671369798725, 'loss': 0.05757994204759598}
# {'epoch': 35, 'iter': 40, 'avg_loss': 0.05855965650663143, 'loss': 0.057102229446172714}
# EP_train:35: 100% 46/46 [00:24<00:00,  1.89it/s]
# EP35, train_loss=0.05854, validate_loss=0.04565
# {'epoch': 36, 'iter': 0, 'avg_loss': 0.05657816678285599, 'loss': 0.05657816678285599}
# {'epoch': 36, 'iter': 10, 'avg_loss': 0.05823687904260375, 'loss': 0.06036395579576492}
# {'epoch': 36, 'iter': 20, 'avg_loss': 0.05831904301331157, 'loss': 0.05926097184419632}
# {'epoch': 36, 'iter': 30, 'avg_loss': 0.05844224388560941, 'loss': 0.05840584263205528}
# {'epoch': 36, 'iter': 40, 'avg_loss': 0.058150536039980445, 'loss': 0.05404389277100563}
# EP_train:36: 100% 46/46 [00:24<00:00,  1.87it/s]
# EP36, train_loss=0.05812, validate_loss=0.04359
# EP:36 Model Saved on: /content/drive/MyDrive/checkpoints/pretraincheckpoint.tar
# {'epoch': 37, 'iter': 0, 'avg_loss': 0.05316425487399101, 'loss': 0.05316425487399101}
# {'epoch': 37, 'iter': 10, 'avg_loss': 0.05642843618988991, 'loss': 0.05636601895093918}
# {'epoch': 37, 'iter': 20, 'avg_loss': 0.056442685247886745, 'loss': 0.05766842141747475}
# {'epoch': 37, 'iter': 30, 'avg_loss': 0.056626246581154484, 'loss': 0.056646957993507385}
# {'epoch': 37, 'iter': 40, 'avg_loss': 0.05664069359985793, 'loss': 0.05828721076250076}
# EP_train:37: 100% 46/46 [00:24<00:00,  1.88it/s]
# EP37, train_loss=0.05660, validate_loss=0.04197
# EP:37 Model Saved on: /content/drive/MyDrive/checkpoints/pretraincheckpoint.tar
# {'epoch': 38, 'iter': 0, 'avg_loss': 0.05655673146247864, 'loss': 0.05655673146247864}
# {'epoch': 38, 'iter': 10, 'avg_loss': 0.05671708997000347, 'loss': 0.05554855987429619}
# {'epoch': 38, 'iter': 20, 'avg_loss': 0.05641444328994978, 'loss': 0.05710368603467941}
# {'epoch': 38, 'iter': 30, 'avg_loss': 0.05640994709345602, 'loss': 0.05901862680912018}
# {'epoch': 38, 'iter': 40, 'avg_loss': 0.056394868598478594, 'loss': 0.05647723376750946}
# EP_train:38: 100% 46/46 [00:24<00:00,  1.88it/s]
# EP38, train_loss=0.05631, validate_loss=0.03881
# EP:38 Model Saved on: /content/drive/MyDrive/checkpoints/pretraincheckpoint.tar
# {'epoch': 39, 'iter': 0, 'avg_loss': 0.051377251744270325, 'loss': 0.051377251744270325}
# {'epoch': 39, 'iter': 10, 'avg_loss': 0.05519654737277464, 'loss': 0.05434388667345047}
# {'epoch': 39, 'iter': 20, 'avg_loss': 0.05511353218129703, 'loss': 0.05410630255937576}
# {'epoch': 39, 'iter': 30, 'avg_loss': 0.055413112885529, 'loss': 0.056205686181783676}
# {'epoch': 39, 'iter': 40, 'avg_loss': 0.05536990948930019, 'loss': 0.05488462373614311}
# EP_train:39: 100% 46/46 [00:24<00:00,  1.85it/s]
# EP39, train_loss=0.05520, validate_loss=0.04038
# {'epoch': 40, 'iter': 0, 'avg_loss': 0.05212607979774475, 'loss': 0.05212607979774475}
# {'epoch': 40, 'iter': 10, 'avg_loss': 0.054961501536044205, 'loss': 0.05623837560415268}
# {'epoch': 40, 'iter': 20, 'avg_loss': 0.054811258223794755, 'loss': 0.05341032147407532}
# {'epoch': 40, 'iter': 30, 'avg_loss': 0.05465421777579092, 'loss': 0.05519093945622444}
# {'epoch': 40, 'iter': 40, 'avg_loss': 0.054574800428093935, 'loss': 0.0498603880405426}
# EP_train:40: 100% 46/46 [00:24<00:00,  1.89it/s]
# EP40, train_loss=0.05458, validate_loss=0.04512
# {'epoch': 41, 'iter': 0, 'avg_loss': 0.05687575787305832, 'loss': 0.05687575787305832}
# {'epoch': 41, 'iter': 10, 'avg_loss': 0.055030889131806114, 'loss': 0.05540020391345024}
# {'epoch': 41, 'iter': 20, 'avg_loss': 0.05393607595137188, 'loss': 0.05180339142680168}
# {'epoch': 41, 'iter': 30, 'avg_loss': 0.05368903759987124, 'loss': 0.052069902420043945}
# {'epoch': 41, 'iter': 40, 'avg_loss': 0.0537295038016831, 'loss': 0.05399138852953911}
# EP_train:41: 100% 46/46 [00:24<00:00,  1.88it/s]
# EP41, train_loss=0.05363, validate_loss=0.04610
# {'epoch': 42, 'iter': 0, 'avg_loss': 0.05465729907155037, 'loss': 0.05465729907155037}
# {'epoch': 42, 'iter': 10, 'avg_loss': 0.0533116263422099, 'loss': 0.05262641981244087}
# {'epoch': 42, 'iter': 20, 'avg_loss': 0.05297878952253433, 'loss': 0.052916284650564194}
# {'epoch': 42, 'iter': 30, 'avg_loss': 0.052611518891588334, 'loss': 0.05480025336146355}
# {'epoch': 42, 'iter': 40, 'avg_loss': 0.05260915200157863, 'loss': 0.0525166317820549}
# EP_train:42: 100% 46/46 [00:24<00:00,  1.88it/s]
# EP42, train_loss=0.05246, validate_loss=0.04229
# {'epoch': 43, 'iter': 0, 'avg_loss': 0.05291038379073143, 'loss': 0.05291038379073143}
# {'epoch': 43, 'iter': 10, 'avg_loss': 0.052802066911350594, 'loss': 0.053985144942998886}
# {'epoch': 43, 'iter': 20, 'avg_loss': 0.05263992647329966, 'loss': 0.05624174699187279}
# {'epoch': 43, 'iter': 30, 'avg_loss': 0.05253758509793589, 'loss': 0.052048418670892715}
# {'epoch': 43, 'iter': 40, 'avg_loss': 0.052319922916046, 'loss': 0.051338743418455124}
# EP_train:43: 100% 46/46 [00:24<00:00,  1.89it/s]
# EP43, train_loss=0.05225, validate_loss=0.04016
# {'epoch': 44, 'iter': 0, 'avg_loss': 0.05838917940855026, 'loss': 0.05838917940855026}
# {'epoch': 44, 'iter': 10, 'avg_loss': 0.052681338380683555, 'loss': 0.05304072052240372}
# {'epoch': 44, 'iter': 20, 'avg_loss': 0.052336866302149634, 'loss': 0.05019031837582588}
# {'epoch': 44, 'iter': 30, 'avg_loss': 0.052094395242391095, 'loss': 0.05011821165680885}
# {'epoch': 44, 'iter': 40, 'avg_loss': 0.05180512414109416, 'loss': 0.05187374725937843}
# EP_train:44: 100% 46/46 [00:24<00:00,  1.89it/s]
# EP44, train_loss=0.05184, validate_loss=0.04076
# {'epoch': 45, 'iter': 0, 'avg_loss': 0.04730021953582764, 'loss': 0.04730021953582764}
# {'epoch': 45, 'iter': 10, 'avg_loss': 0.051058043133128776, 'loss': 0.05259475111961365}
# {'epoch': 45, 'iter': 20, 'avg_loss': 0.050775162698257534, 'loss': 0.05281629413366318}
# {'epoch': 45, 'iter': 30, 'avg_loss': 0.05087163972277795, 'loss': 0.05399511754512787}
# {'epoch': 45, 'iter': 40, 'avg_loss': 0.050830710406710465, 'loss': 0.053353048861026764}
# EP_train:45: 100% 46/46 [00:24<00:00,  1.86it/s]
# EP45, train_loss=0.05097, validate_loss=0.04022
# {'epoch': 46, 'iter': 0, 'avg_loss': 0.050454430282115936, 'loss': 0.050454430282115936}
# {'epoch': 46, 'iter': 10, 'avg_loss': 0.05151041427796537, 'loss': 0.049264226108789444}
# {'epoch': 46, 'iter': 20, 'avg_loss': 0.05176502164630663, 'loss': 0.04985601454973221}
# {'epoch': 46, 'iter': 30, 'avg_loss': 0.05123625503432366, 'loss': 0.050985559821128845}
# {'epoch': 46, 'iter': 40, 'avg_loss': 0.051141435598454826, 'loss': 0.0531289167702198}
# EP_train:46: 100% 46/46 [00:24<00:00,  1.90it/s]
# EP46, train_loss=0.05113, validate_loss=0.03622
# EP:46 Model Saved on: /content/drive/MyDrive/checkpoints/pretraincheckpoint.tar
# {'epoch': 47, 'iter': 0, 'avg_loss': 0.05136502534151077, 'loss': 0.05136502534151077}
# {'epoch': 47, 'iter': 10, 'avg_loss': 0.049914765764366494, 'loss': 0.04946867376565933}
# {'epoch': 47, 'iter': 20, 'avg_loss': 0.049404426522198175, 'loss': 0.0522279366850853}
# {'epoch': 47, 'iter': 30, 'avg_loss': 0.0498226675535402, 'loss': 0.05283665657043457}
# {'epoch': 47, 'iter': 40, 'avg_loss': 0.04983909264570329, 'loss': 0.04982667416334152}
# EP_train:47: 100% 46/46 [00:24<00:00,  1.88it/s]
# EP47, train_loss=0.04964, validate_loss=0.03732
# {'epoch': 48, 'iter': 0, 'avg_loss': 0.05233481153845787, 'loss': 0.05233481153845787}
# {'epoch': 48, 'iter': 10, 'avg_loss': 0.05009816146709702, 'loss': 0.05019287392497063}
# {'epoch': 48, 'iter': 20, 'avg_loss': 0.04996217592131524, 'loss': 0.04807676374912262}
# {'epoch': 48, 'iter': 30, 'avg_loss': 0.04988387359246131, 'loss': 0.04718119651079178}
# {'epoch': 48, 'iter': 40, 'avg_loss': 0.04961376519101422, 'loss': 0.04880557954311371}
# EP_train:48: 100% 46/46 [00:24<00:00,  1.89it/s]
# EP48, train_loss=0.04965, validate_loss=0.04225
# {'epoch': 49, 'iter': 0, 'avg_loss': 0.048725664615631104, 'loss': 0.048725664615631104}
# {'epoch': 49, 'iter': 10, 'avg_loss': 0.04929164864800193, 'loss': 0.051251012831926346}
# {'epoch': 49, 'iter': 20, 'avg_loss': 0.049350028591496606, 'loss': 0.0495695024728775}
# {'epoch': 49, 'iter': 30, 'avg_loss': 0.049359668647089315, 'loss': 0.048322923481464386}
# {'epoch': 49, 'iter': 40, 'avg_loss': 0.049363339001812584, 'loss': 0.049673892557621}
# EP_train:49: 100% 46/46 [00:24<00:00,  1.88it/s]
# EP49, train_loss=0.04929, validate_loss=0.03797
# {'epoch': 50, 'iter': 0, 'avg_loss': 0.05020640790462494, 'loss': 0.05020640790462494}
# {'epoch': 50, 'iter': 10, 'avg_loss': 0.048556471074169334, 'loss': 0.04665903002023697}
# {'epoch': 50, 'iter': 20, 'avg_loss': 0.048612474508228753, 'loss': 0.0476498119533062}
# {'epoch': 50, 'iter': 30, 'avg_loss': 0.0486688976806979, 'loss': 0.047459088265895844}
# {'epoch': 50, 'iter': 40, 'avg_loss': 0.04851102383761871, 'loss': 0.048437923192977905}
# EP_train:50: 100% 46/46 [00:24<00:00,  1.88it/s]
# EP50, train_loss=0.04841, validate_loss=0.04014
# {'epoch': 51, 'iter': 0, 'avg_loss': 0.04967409744858742, 'loss': 0.04967409744858742}
# {'epoch': 51, 'iter': 10, 'avg_loss': 0.04901614819060673, 'loss': 0.049584995955228806}
# {'epoch': 51, 'iter': 20, 'avg_loss': 0.04859875479624385, 'loss': 0.050697386264801025}
# {'epoch': 51, 'iter': 30, 'avg_loss': 0.04852371518650363, 'loss': 0.05035465210676193}
# {'epoch': 51, 'iter': 40, 'avg_loss': 0.04818199783927057, 'loss': 0.04628774896264076}
# EP_train:51: 100% 46/46 [00:24<00:00,  1.88it/s]
# EP51, train_loss=0.04805, validate_loss=0.03972
# {'epoch': 52, 'iter': 0, 'avg_loss': 0.04442694038152695, 'loss': 0.04442694038152695}
# {'epoch': 52, 'iter': 10, 'avg_loss': 0.048209700056097725, 'loss': 0.04964025318622589}
# {'epoch': 52, 'iter': 20, 'avg_loss': 0.04796353745318595, 'loss': 0.05004571005702019}
# {'epoch': 52, 'iter': 30, 'avg_loss': 0.047925132537080396, 'loss': 0.04883170127868652}
# {'epoch': 52, 'iter': 40, 'avg_loss': 0.04748210701637152, 'loss': 0.04800155758857727}
# EP_train:52: 100% 46/46 [00:24<00:00,  1.86it/s]
# EP52, train_loss=0.04754, validate_loss=0.03915
# {'epoch': 53, 'iter': 0, 'avg_loss': 0.04689057171344757, 'loss': 0.04689057171344757}
# {'epoch': 53, 'iter': 10, 'avg_loss': 0.047816038470376625, 'loss': 0.05097407475113869}
# {'epoch': 53, 'iter': 20, 'avg_loss': 0.04758841615347635, 'loss': 0.04628688097000122}
# {'epoch': 53, 'iter': 30, 'avg_loss': 0.04746498431890241, 'loss': 0.04703954979777336}
# {'epoch': 53, 'iter': 40, 'avg_loss': 0.04734830176684915, 'loss': 0.045221492648124695}
# EP_train:53: 100% 46/46 [00:24<00:00,  1.88it/s]
# EP53, train_loss=0.04721, validate_loss=0.03930
# {'epoch': 54, 'iter': 0, 'avg_loss': 0.04769502580165863, 'loss': 0.04769502580165863}
# {'epoch': 54, 'iter': 10, 'avg_loss': 0.047214101322672584, 'loss': 0.04479767754673958}
# {'epoch': 54, 'iter': 20, 'avg_loss': 0.04697541928007489, 'loss': 0.04478611424565315}
# {'epoch': 54, 'iter': 30, 'avg_loss': 0.04668052302252862, 'loss': 0.046273645013570786}
# {'epoch': 54, 'iter': 40, 'avg_loss': 0.046582193091148284, 'loss': 0.048290882259607315}
# EP_train:54: 100% 46/46 [00:24<00:00,  1.89it/s]
# EP54, train_loss=0.04649, validate_loss=0.03677
# {'epoch': 55, 'iter': 0, 'avg_loss': 0.048996444791555405, 'loss': 0.048996444791555405}
# {'epoch': 55, 'iter': 10, 'avg_loss': 0.04710236293348399, 'loss': 0.04855058342218399}
# {'epoch': 55, 'iter': 20, 'avg_loss': 0.04698994897660755, 'loss': 0.049267496913671494}
# {'epoch': 55, 'iter': 30, 'avg_loss': 0.04658628195043533, 'loss': 0.044644664973020554}
# {'epoch': 55, 'iter': 40, 'avg_loss': 0.04651811410014222, 'loss': 0.04421883076429367}
# EP_train:55: 100% 46/46 [00:24<00:00,  1.88it/s]
# EP55, train_loss=0.04643, validate_loss=0.03707
# {'epoch': 56, 'iter': 0, 'avg_loss': 0.04394310340285301, 'loss': 0.04394310340285301}
# {'epoch': 56, 'iter': 10, 'avg_loss': 0.046543780375610695, 'loss': 0.04559023305773735}
# {'epoch': 56, 'iter': 20, 'avg_loss': 0.04596798991163572, 'loss': 0.04702593386173248}
# {'epoch': 56, 'iter': 30, 'avg_loss': 0.04586214415969387, 'loss': 0.047154948115348816}
# {'epoch': 56, 'iter': 40, 'avg_loss': 0.04600381315117929, 'loss': 0.04322464391589165}
# EP_train:56: 100% 46/46 [00:24<00:00,  1.91it/s]
# EP56, train_loss=0.04603, validate_loss=0.03511
# EP:56 Model Saved on: /content/drive/MyDrive/checkpoints/pretraincheckpoint.tar
# {'epoch': 57, 'iter': 0, 'avg_loss': 0.04664837196469307, 'loss': 0.04664837196469307}
# {'epoch': 57, 'iter': 10, 'avg_loss': 0.04578248445283283, 'loss': 0.043843626976013184}
# {'epoch': 57, 'iter': 20, 'avg_loss': 0.04578262017596336, 'loss': 0.04516364634037018}
# {'epoch': 57, 'iter': 30, 'avg_loss': 0.045718942438402486, 'loss': 0.04528152942657471}
# {'epoch': 57, 'iter': 40, 'avg_loss': 0.04570254356395907, 'loss': 0.044544730335474014}
# EP_train:57: 100% 46/46 [00:24<00:00,  1.88it/s]
# EP57, train_loss=0.04555, validate_loss=0.03769
# {'epoch': 58, 'iter': 0, 'avg_loss': 0.04357530176639557, 'loss': 0.04357530176639557}
# {'epoch': 58, 'iter': 10, 'avg_loss': 0.04500586539506912, 'loss': 0.04672755300998688}
# {'epoch': 58, 'iter': 20, 'avg_loss': 0.04494960144871757, 'loss': 0.04494890943169594}
# {'epoch': 58, 'iter': 30, 'avg_loss': 0.045094592196326104, 'loss': 0.04561397060751915}
# {'epoch': 58, 'iter': 40, 'avg_loss': 0.04532182779980869, 'loss': 0.04890706017613411}
# EP_train:58: 100% 46/46 [00:24<00:00,  1.90it/s]
# EP58, train_loss=0.04523, validate_loss=0.03483
# EP:58 Model Saved on: /content/drive/MyDrive/checkpoints/pretraincheckpoint.tar
# {'epoch': 59, 'iter': 0, 'avg_loss': 0.0432535782456398, 'loss': 0.0432535782456398}
# {'epoch': 59, 'iter': 10, 'avg_loss': 0.04506607218222185, 'loss': 0.04583681374788284}
# {'epoch': 59, 'iter': 20, 'avg_loss': 0.04454391006202925, 'loss': 0.04633080214262009}
# {'epoch': 59, 'iter': 30, 'avg_loss': 0.04450953174983301, 'loss': 0.04243726283311844}
# {'epoch': 59, 'iter': 40, 'avg_loss': 0.04440200274310461, 'loss': 0.040978364646434784}
# EP_train:59: 100% 46/46 [00:24<00:00,  1.86it/s]
# EP59, train_loss=0.04445, validate_loss=0.03762
# {'epoch': 60, 'iter': 0, 'avg_loss': 0.04448770731687546, 'loss': 0.04448770731687546}
# {'epoch': 60, 'iter': 10, 'avg_loss': 0.04446295513348146, 'loss': 0.04263035207986832}
# {'epoch': 60, 'iter': 20, 'avg_loss': 0.04449170348899705, 'loss': 0.043955013155937195}
# {'epoch': 60, 'iter': 30, 'avg_loss': 0.04423277933270701, 'loss': 0.043257661163806915}
# {'epoch': 60, 'iter': 40, 'avg_loss': 0.044483520272301465, 'loss': 0.04370522126555443}
# EP_train:60: 100% 46/46 [00:24<00:00,  1.88it/s]
# EP60, train_loss=0.04442, validate_loss=0.03550
# {'epoch': 61, 'iter': 0, 'avg_loss': 0.0451943501830101, 'loss': 0.0451943501830101}
# {'epoch': 61, 'iter': 10, 'avg_loss': 0.045143273743716156, 'loss': 0.044095706194639206}
# {'epoch': 61, 'iter': 20, 'avg_loss': 0.04485718178607169, 'loss': 0.046470265835523605}
# {'epoch': 61, 'iter': 30, 'avg_loss': 0.044536707261877674, 'loss': 0.0414661169052124}
# {'epoch': 61, 'iter': 40, 'avg_loss': 0.044390115523483695, 'loss': 0.041050687432289124}
# EP_train:61: 100% 46/46 [00:24<00:00,  1.90it/s]
# EP61, train_loss=0.04434, validate_loss=0.03718
# {'epoch': 62, 'iter': 0, 'avg_loss': 0.04473234340548515, 'loss': 0.04473234340548515}
# {'epoch': 62, 'iter': 10, 'avg_loss': 0.043449804186820984, 'loss': 0.0423603355884552}
# {'epoch': 62, 'iter': 20, 'avg_loss': 0.043949320734966366, 'loss': 0.04600661247968674}
# {'epoch': 62, 'iter': 30, 'avg_loss': 0.04378733363363051, 'loss': 0.04190627112984657}
# {'epoch': 62, 'iter': 40, 'avg_loss': 0.044307801145605924, 'loss': 0.04482492431998253}
# EP_train:62: 100% 46/46 [00:24<00:00,  1.86it/s]
# EP62, train_loss=0.04437, validate_loss=0.03430
# EP:62 Model Saved on: /content/drive/MyDrive/checkpoints/pretraincheckpoint.tar
# {'epoch': 63, 'iter': 0, 'avg_loss': 0.04323280230164528, 'loss': 0.04323280230164528}
# {'epoch': 63, 'iter': 10, 'avg_loss': 0.04422171481631019, 'loss': 0.0433945395052433}
# {'epoch': 63, 'iter': 20, 'avg_loss': 0.04355963301800546, 'loss': 0.04293368384242058}
# {'epoch': 63, 'iter': 30, 'avg_loss': 0.043672247038733576, 'loss': 0.04640161618590355}
# {'epoch': 63, 'iter': 40, 'avg_loss': 0.04380080703555084, 'loss': 0.04547268524765968}
# EP_train:63: 100% 46/46 [00:24<00:00,  1.87it/s]
# EP63, train_loss=0.04375, validate_loss=0.03368
# EP:63 Model Saved on: /content/drive/MyDrive/checkpoints/pretraincheckpoint.tar
# {'epoch': 64, 'iter': 0, 'avg_loss': 0.04329491779208183, 'loss': 0.04329491779208183}
# {'epoch': 64, 'iter': 10, 'avg_loss': 0.043529519641941246, 'loss': 0.04345206916332245}
# {'epoch': 64, 'iter': 20, 'avg_loss': 0.0435708211291404, 'loss': 0.044422347098588943}
# {'epoch': 64, 'iter': 30, 'avg_loss': 0.04343233449805167, 'loss': 0.04284554347395897}
# {'epoch': 64, 'iter': 40, 'avg_loss': 0.043342190817361924, 'loss': 0.042267341166734695}
# EP_train:64: 100% 46/46 [00:24<00:00,  1.88it/s]
# EP64, train_loss=0.04324, validate_loss=0.03655
# {'epoch': 65, 'iter': 0, 'avg_loss': 0.04082563519477844, 'loss': 0.04082563519477844}
# {'epoch': 65, 'iter': 10, 'avg_loss': 0.043396146121350204, 'loss': 0.043234121054410934}
# {'epoch': 65, 'iter': 20, 'avg_loss': 0.04308626889472916, 'loss': 0.04481250420212746}
# {'epoch': 65, 'iter': 30, 'avg_loss': 0.0433905974270836, 'loss': 0.0464700348675251}
# {'epoch': 65, 'iter': 40, 'avg_loss': 0.043340125189321795, 'loss': 0.04242614284157753}
# EP_train:65: 100% 46/46 [00:24<00:00,  1.90it/s]
# EP65, train_loss=0.04335, validate_loss=0.03602
# {'epoch': 66, 'iter': 0, 'avg_loss': 0.041556403040885925, 'loss': 0.041556403040885925}
# {'epoch': 66, 'iter': 10, 'avg_loss': 0.042229017412120644, 'loss': 0.041574589908123016}
# {'epoch': 66, 'iter': 20, 'avg_loss': 0.042583724217755456, 'loss': 0.03925958275794983}
# {'epoch': 66, 'iter': 30, 'avg_loss': 0.0427443710786681, 'loss': 0.04118247330188751}
# {'epoch': 66, 'iter': 40, 'avg_loss': 0.04291405610558463, 'loss': 0.04356619715690613}
# EP_train:66: 100% 46/46 [00:24<00:00,  1.87it/s]
# EP66, train_loss=0.04302, validate_loss=0.03517
# {'epoch': 67, 'iter': 0, 'avg_loss': 0.043308887630701065, 'loss': 0.043308887630701065}
# {'epoch': 67, 'iter': 10, 'avg_loss': 0.0436412397433411, 'loss': 0.04239188879728317}
# {'epoch': 67, 'iter': 20, 'avg_loss': 0.04327471465581939, 'loss': 0.04256388917565346}
# {'epoch': 67, 'iter': 30, 'avg_loss': 0.042987493738051386, 'loss': 0.04423173516988754}
# {'epoch': 67, 'iter': 40, 'avg_loss': 0.04303520981494973, 'loss': 0.043553199619054794}
# EP_train:67: 100% 46/46 [00:24<00:00,  1.89it/s]
# EP67, train_loss=0.04288, validate_loss=0.03849
# {'epoch': 68, 'iter': 0, 'avg_loss': 0.04384908452630043, 'loss': 0.04384908452630043}
# {'epoch': 68, 'iter': 10, 'avg_loss': 0.04317570985718207, 'loss': 0.04180348664522171}
# {'epoch': 68, 'iter': 20, 'avg_loss': 0.042818326503038406, 'loss': 0.043288759887218475}
# {'epoch': 68, 'iter': 30, 'avg_loss': 0.042795090305228385, 'loss': 0.04317157715559006}
# {'epoch': 68, 'iter': 40, 'avg_loss': 0.04274621978402138, 'loss': 0.04036601260304451}
# EP_train:68: 100% 46/46 [00:24<00:00,  1.89it/s]
# EP68, train_loss=0.04269, validate_loss=0.03482
# {'epoch': 69, 'iter': 0, 'avg_loss': 0.04222126305103302, 'loss': 0.04222126305103302}
# {'epoch': 69, 'iter': 10, 'avg_loss': 0.04346274652264335, 'loss': 0.041464488953351974}
# {'epoch': 69, 'iter': 20, 'avg_loss': 0.0423128805345013, 'loss': 0.04288345202803612}
# {'epoch': 69, 'iter': 30, 'avg_loss': 0.0421821131340919, 'loss': 0.04051775857806206}
# {'epoch': 69, 'iter': 40, 'avg_loss': 0.04202850853524557, 'loss': 0.03893143683671951}
# EP_train:69: 100% 46/46 [00:24<00:00,  1.87it/s]
# EP69, train_loss=0.04199, validate_loss=0.03614
# {'epoch': 70, 'iter': 0, 'avg_loss': 0.039508137851953506, 'loss': 0.039508137851953506}
# {'epoch': 70, 'iter': 10, 'avg_loss': 0.041690561920404434, 'loss': 0.04151615872979164}
# {'epoch': 70, 'iter': 20, 'avg_loss': 0.04206060813296409, 'loss': 0.04355635121464729}
# {'epoch': 70, 'iter': 30, 'avg_loss': 0.04226388073255939, 'loss': 0.04312743991613388}
# {'epoch': 70, 'iter': 40, 'avg_loss': 0.04199798441514736, 'loss': 0.04150187224149704}
# EP_train:70: 100% 46/46 [00:24<00:00,  1.88it/s]
# EP70, train_loss=0.04180, validate_loss=0.03363
# EP:70 Model Saved on: /content/drive/MyDrive/checkpoints/pretraincheckpoint.tar
# {'epoch': 71, 'iter': 0, 'avg_loss': 0.041639573872089386, 'loss': 0.041639573872089386}
# {'epoch': 71, 'iter': 10, 'avg_loss': 0.041089382699944756, 'loss': 0.04004916548728943}
# {'epoch': 71, 'iter': 20, 'avg_loss': 0.04112020613891738, 'loss': 0.04080042988061905}
# {'epoch': 71, 'iter': 30, 'avg_loss': 0.04136379760119223, 'loss': 0.03977722302079201}
# {'epoch': 71, 'iter': 40, 'avg_loss': 0.041631835262949876, 'loss': 0.04276252165436745}
# EP_train:71: 100% 46/46 [00:24<00:00,  1.87it/s]
# EP71, train_loss=0.04173, validate_loss=0.03488
# {'epoch': 72, 'iter': 0, 'avg_loss': 0.03992700204253197, 'loss': 0.03992700204253197}
# {'epoch': 72, 'iter': 10, 'avg_loss': 0.04189574379812588, 'loss': 0.042048629373311996}
# {'epoch': 72, 'iter': 20, 'avg_loss': 0.04163785527149836, 'loss': 0.04349870979785919}
# {'epoch': 72, 'iter': 30, 'avg_loss': 0.041544427314112266, 'loss': 0.039169564843177795}
# {'epoch': 72, 'iter': 40, 'avg_loss': 0.041396946441836474, 'loss': 0.04014791175723076}
# EP_train:72: 100% 46/46 [00:24<00:00,  1.89it/s]
# EP72, train_loss=0.04143, validate_loss=0.03453
# {'epoch': 73, 'iter': 0, 'avg_loss': 0.04026167094707489, 'loss': 0.04026167094707489}
# {'epoch': 73, 'iter': 10, 'avg_loss': 0.041138620200482284, 'loss': 0.04190392419695854}
# {'epoch': 73, 'iter': 20, 'avg_loss': 0.04124239158062708, 'loss': 0.04062029719352722}
# {'epoch': 73, 'iter': 30, 'avg_loss': 0.04148004913041668, 'loss': 0.04159177467226982}
# {'epoch': 73, 'iter': 40, 'avg_loss': 0.04125604278794149, 'loss': 0.040290046483278275}
# EP_train:73: 100% 46/46 [00:24<00:00,  1.89it/s]
# EP73, train_loss=0.04131, validate_loss=0.03526
# {'epoch': 74, 'iter': 0, 'avg_loss': 0.041346628218889236, 'loss': 0.041346628218889236}
# {'epoch': 74, 'iter': 10, 'avg_loss': 0.04088571091944521, 'loss': 0.040737684816122055}
# {'epoch': 74, 'iter': 20, 'avg_loss': 0.041087337193034944, 'loss': 0.03947548568248749}
# {'epoch': 74, 'iter': 30, 'avg_loss': 0.041036787653161634, 'loss': 0.037912946194410324}
# {'epoch': 74, 'iter': 40, 'avg_loss': 0.04078680331387171, 'loss': 0.03904463350772858}
# EP_train:74: 100% 46/46 [00:24<00:00,  1.88it/s]
# EP74, train_loss=0.04077, validate_loss=0.03404
# {'epoch': 75, 'iter': 0, 'avg_loss': 0.041439589112997055, 'loss': 0.041439589112997055}
# {'epoch': 75, 'iter': 10, 'avg_loss': 0.04067740758711642, 'loss': 0.04065429046750069}
# {'epoch': 75, 'iter': 20, 'avg_loss': 0.04121961710708482, 'loss': 0.04297657310962677}
# {'epoch': 75, 'iter': 30, 'avg_loss': 0.041148277660531384, 'loss': 0.04155391827225685}
# {'epoch': 75, 'iter': 40, 'avg_loss': 0.041146189428684185, 'loss': 0.04103253409266472}
# EP_train:75: 100% 46/46 [00:24<00:00,  1.88it/s]
# EP75, train_loss=0.04108, validate_loss=0.03200
# EP:75 Model Saved on: /content/drive/MyDrive/checkpoints/pretraincheckpoint.tar
# {'epoch': 76, 'iter': 0, 'avg_loss': 0.04167670011520386, 'loss': 0.04167670011520386}
# {'epoch': 76, 'iter': 10, 'avg_loss': 0.04101515087214383, 'loss': 0.0416501984000206}
# {'epoch': 76, 'iter': 20, 'avg_loss': 0.04099045729353314, 'loss': 0.03929879143834114}
# {'epoch': 76, 'iter': 30, 'avg_loss': 0.04102777221029805, 'loss': 0.039862241595983505}
# {'epoch': 76, 'iter': 40, 'avg_loss': 0.04109622801585895, 'loss': 0.040686652064323425}
# EP_train:76: 100% 46/46 [00:24<00:00,  1.85it/s]
# EP76, train_loss=0.04109, validate_loss=0.03297
# {'epoch': 77, 'iter': 0, 'avg_loss': 0.03997202590107918, 'loss': 0.03997202590107918}
# {'epoch': 77, 'iter': 10, 'avg_loss': 0.04088216071779078, 'loss': 0.04047626256942749}
# {'epoch': 77, 'iter': 20, 'avg_loss': 0.04080507886551675, 'loss': 0.0385926179587841}
# {'epoch': 77, 'iter': 30, 'avg_loss': 0.04051804506490307, 'loss': 0.040351368486881256}
# {'epoch': 77, 'iter': 40, 'avg_loss': 0.040443878893445175, 'loss': 0.0397283211350441}
# EP_train:77: 100% 46/46 [00:24<00:00,  1.88it/s]
# EP77, train_loss=0.04044, validate_loss=0.03972
# {'epoch': 78, 'iter': 0, 'avg_loss': 0.03883815184235573, 'loss': 0.03883815184235573}
# {'epoch': 78, 'iter': 10, 'avg_loss': 0.040189866653897545, 'loss': 0.040321942418813705}
# {'epoch': 78, 'iter': 20, 'avg_loss': 0.04056671190829504, 'loss': 0.03927161917090416}
# {'epoch': 78, 'iter': 30, 'avg_loss': 0.04072903445170772, 'loss': 0.04259594902396202}
# {'epoch': 78, 'iter': 40, 'avg_loss': 0.04054936185115721, 'loss': 0.03999423235654831}
# EP_train:78: 100% 46/46 [00:24<00:00,  1.88it/s]
# EP78, train_loss=0.04050, validate_loss=0.03311
# {'epoch': 79, 'iter': 0, 'avg_loss': 0.03971048817038536, 'loss': 0.03971048817038536}
# {'epoch': 79, 'iter': 10, 'avg_loss': 0.03966674682768909, 'loss': 0.04016141965985298}
# {'epoch': 79, 'iter': 20, 'avg_loss': 0.03997207929690679, 'loss': 0.03858187049627304}
# {'epoch': 79, 'iter': 30, 'avg_loss': 0.04020049759457188, 'loss': 0.040995728224515915}
# {'epoch': 79, 'iter': 40, 'avg_loss': 0.04000740916263766, 'loss': 0.038250017911195755}
# EP_train:79: 100% 46/46 [00:24<00:00,  1.88it/s]
# EP79, train_loss=0.03996, validate_loss=0.03311
# {'epoch': 80, 'iter': 0, 'avg_loss': 0.04300728440284729, 'loss': 0.04300728440284729}
# {'epoch': 80, 'iter': 10, 'avg_loss': 0.03961060839620503, 'loss': 0.03865401819348335}
# {'epoch': 80, 'iter': 20, 'avg_loss': 0.039960467034862154, 'loss': 0.04198763519525528}
# {'epoch': 80, 'iter': 30, 'avg_loss': 0.04004909122182477, 'loss': 0.04184470698237419}
# {'epoch': 80, 'iter': 40, 'avg_loss': 0.0401040099379493, 'loss': 0.03904639557003975}
# EP_train:80: 100% 46/46 [00:24<00:00,  1.87it/s]
# EP80, train_loss=0.04004, validate_loss=0.03569
# {'epoch': 81, 'iter': 0, 'avg_loss': 0.04058282822370529, 'loss': 0.04058282822370529}
# {'epoch': 81, 'iter': 10, 'avg_loss': 0.040579537099057976, 'loss': 0.042038772255182266}
# {'epoch': 81, 'iter': 20, 'avg_loss': 0.040042360623677574, 'loss': 0.04044461250305176}
# {'epoch': 81, 'iter': 30, 'avg_loss': 0.039957048792031505, 'loss': 0.04039637744426727}
# {'epoch': 81, 'iter': 40, 'avg_loss': 0.0400247401217135, 'loss': 0.043429769575595856}
# EP_train:81: 100% 46/46 [00:24<00:00,  1.91it/s]
# EP81, train_loss=0.03989, validate_loss=0.03085
# EP:81 Model Saved on: /content/drive/MyDrive/checkpoints/pretraincheckpoint.tar
# {'epoch': 82, 'iter': 0, 'avg_loss': 0.04069962352514267, 'loss': 0.04069962352514267}
# {'epoch': 82, 'iter': 10, 'avg_loss': 0.03965698927640915, 'loss': 0.0392480343580246}
# {'epoch': 82, 'iter': 20, 'avg_loss': 0.03960334562829563, 'loss': 0.041187185794115067}
# {'epoch': 82, 'iter': 30, 'avg_loss': 0.03961902700604931, 'loss': 0.04132667928934097}
# {'epoch': 82, 'iter': 40, 'avg_loss': 0.039647623896598816, 'loss': 0.036932699382305145}
# EP_train:82: 100% 46/46 [00:24<00:00,  1.91it/s]
# EP82, train_loss=0.03952, validate_loss=0.03118
# {'epoch': 83, 'iter': 0, 'avg_loss': 0.038412146270275116, 'loss': 0.038412146270275116}
# {'epoch': 83, 'iter': 10, 'avg_loss': 0.03867032649842175, 'loss': 0.038392823189496994}
# {'epoch': 83, 'iter': 20, 'avg_loss': 0.03882187250114623, 'loss': 0.040397435426712036}
# {'epoch': 83, 'iter': 30, 'avg_loss': 0.03896460946529142, 'loss': 0.040529362857341766}
# {'epoch': 83, 'iter': 40, 'avg_loss': 0.03893956151313898, 'loss': 0.0370045006275177}
# EP_train:83: 100% 46/46 [00:24<00:00,  1.89it/s]
# EP83, train_loss=0.03895, validate_loss=0.03281
# {'epoch': 84, 'iter': 0, 'avg_loss': 0.04119414463639259, 'loss': 0.04119414463639259}
# {'epoch': 84, 'iter': 10, 'avg_loss': 0.039763643998991356, 'loss': 0.038958895951509476}
# {'epoch': 84, 'iter': 20, 'avg_loss': 0.039788221496911275, 'loss': 0.03995584324002266}
# {'epoch': 84, 'iter': 30, 'avg_loss': 0.03950201359487349, 'loss': 0.03813771530985832}
# {'epoch': 84, 'iter': 40, 'avg_loss': 0.03941654086839862, 'loss': 0.03987693414092064}
# EP_train:84: 100% 46/46 [00:24<00:00,  1.89it/s]
# EP84, train_loss=0.03923, validate_loss=0.03336
# {'epoch': 85, 'iter': 0, 'avg_loss': 0.04067960008978844, 'loss': 0.04067960008978844}
# {'epoch': 85, 'iter': 10, 'avg_loss': 0.03926930339498953, 'loss': 0.03859454765915871}
# {'epoch': 85, 'iter': 20, 'avg_loss': 0.03945417436105864, 'loss': 0.041165318340063095}
# {'epoch': 85, 'iter': 30, 'avg_loss': 0.03948418207226261, 'loss': 0.03875311464071274}
# {'epoch': 85, 'iter': 40, 'avg_loss': 0.03943547788189679, 'loss': 0.038497444242239}
# EP_train:85: 100% 46/46 [00:24<00:00,  1.89it/s]
# EP85, train_loss=0.03944, validate_loss=0.03668
# {'epoch': 86, 'iter': 0, 'avg_loss': 0.04116802290081978, 'loss': 0.04116802290081978}
# {'epoch': 86, 'iter': 10, 'avg_loss': 0.03901479731906544, 'loss': 0.04093657806515694}
# {'epoch': 86, 'iter': 20, 'avg_loss': 0.039100444210427146, 'loss': 0.041983526200056076}
# {'epoch': 86, 'iter': 30, 'avg_loss': 0.039177749666475484, 'loss': 0.038721613585948944}
# {'epoch': 86, 'iter': 40, 'avg_loss': 0.03928814174198523, 'loss': 0.041598472744226456}
# EP_train:86: 100% 46/46 [00:24<00:00,  1.90it/s]
# EP86, train_loss=0.03914, validate_loss=0.03460
# {'epoch': 87, 'iter': 0, 'avg_loss': 0.03839864581823349, 'loss': 0.03839864581823349}
# {'epoch': 87, 'iter': 10, 'avg_loss': 0.03863036835735494, 'loss': 0.03667038306593895}
# {'epoch': 87, 'iter': 20, 'avg_loss': 0.03878058954363778, 'loss': 0.036611828953027725}
# {'epoch': 87, 'iter': 30, 'avg_loss': 0.03874325884446021, 'loss': 0.041212525218725204}
# {'epoch': 87, 'iter': 40, 'avg_loss': 0.03868934721118066, 'loss': 0.039650462567806244}
# EP_train:87: 100% 46/46 [00:24<00:00,  1.88it/s]
# EP87, train_loss=0.03882, validate_loss=0.03059
# EP:87 Model Saved on: /content/drive/MyDrive/checkpoints/pretraincheckpoint.tar
# {'epoch': 88, 'iter': 0, 'avg_loss': 0.04037591442465782, 'loss': 0.04037591442465782}
# {'epoch': 88, 'iter': 10, 'avg_loss': 0.03891709006645463, 'loss': 0.039240237325429916}
# {'epoch': 88, 'iter': 20, 'avg_loss': 0.039186732400031316, 'loss': 0.0395374596118927}
# {'epoch': 88, 'iter': 30, 'avg_loss': 0.03888145966395255, 'loss': 0.0391114205121994}
# {'epoch': 88, 'iter': 40, 'avg_loss': 0.03902828211827976, 'loss': 0.03843490034341812}
# EP_train:88: 100% 46/46 [00:24<00:00,  1.88it/s]
# EP88, train_loss=0.03896, validate_loss=0.03008
# EP:88 Model Saved on: /content/drive/MyDrive/checkpoints/pretraincheckpoint.tar
# {'epoch': 89, 'iter': 0, 'avg_loss': 0.04253210872411728, 'loss': 0.04253210872411728}
# {'epoch': 89, 'iter': 10, 'avg_loss': 0.03885497897863388, 'loss': 0.03631148114800453}
# {'epoch': 89, 'iter': 20, 'avg_loss': 0.03896350928005718, 'loss': 0.03653927147388458}
# {'epoch': 89, 'iter': 30, 'avg_loss': 0.03876972859424929, 'loss': 0.036759406328201294}
# {'epoch': 89, 'iter': 40, 'avg_loss': 0.03874104106571616, 'loss': 0.03631025552749634}
# EP_train:89: 100% 46/46 [00:24<00:00,  1.89it/s]
# EP89, train_loss=0.03879, validate_loss=0.03141
# {'epoch': 90, 'iter': 0, 'avg_loss': 0.03985464200377464, 'loss': 0.03985464200377464}
# {'epoch': 90, 'iter': 10, 'avg_loss': 0.03825817189433358, 'loss': 0.038416147232055664}
# {'epoch': 90, 'iter': 20, 'avg_loss': 0.03860025622305416, 'loss': 0.03800194337964058}
# {'epoch': 90, 'iter': 30, 'avg_loss': 0.038384095435180975, 'loss': 0.03814283758401871}
# {'epoch': 90, 'iter': 40, 'avg_loss': 0.03828551293146319, 'loss': 0.0377839058637619}
# EP_train:90: 100% 46/46 [00:24<00:00,  1.90it/s]
# EP90, train_loss=0.03822, validate_loss=0.03097
# {'epoch': 91, 'iter': 0, 'avg_loss': 0.03791136294603348, 'loss': 0.03791136294603348}
# {'epoch': 91, 'iter': 10, 'avg_loss': 0.03884641250426119, 'loss': 0.037926435470581055}
# {'epoch': 91, 'iter': 20, 'avg_loss': 0.03881332083117394, 'loss': 0.038922280073165894}
# {'epoch': 91, 'iter': 30, 'avg_loss': 0.038484979420900345, 'loss': 0.03632688894867897}
# {'epoch': 91, 'iter': 40, 'avg_loss': 0.03841048451821979, 'loss': 0.03709635138511658}
# EP_train:91: 100% 46/46 [00:24<00:00,  1.88it/s]
# EP91, train_loss=0.03834, validate_loss=0.03356
# {'epoch': 92, 'iter': 0, 'avg_loss': 0.040195267647504807, 'loss': 0.040195267647504807}
# {'epoch': 92, 'iter': 10, 'avg_loss': 0.03765947236256166, 'loss': 0.03858262300491333}
# {'epoch': 92, 'iter': 20, 'avg_loss': 0.03797957584971473, 'loss': 0.0380714051425457}
# {'epoch': 92, 'iter': 30, 'avg_loss': 0.03812086305791332, 'loss': 0.035630375146865845}
# {'epoch': 92, 'iter': 40, 'avg_loss': 0.03824968581519476, 'loss': 0.0391182005405426}
# EP_train:92: 100% 46/46 [00:24<00:00,  1.88it/s]
# EP92, train_loss=0.03830, validate_loss=0.03101
# {'epoch': 93, 'iter': 0, 'avg_loss': 0.037538282573223114, 'loss': 0.037538282573223114}
# {'epoch': 93, 'iter': 10, 'avg_loss': 0.037251519885930146, 'loss': 0.03761101886630058}
# {'epoch': 93, 'iter': 20, 'avg_loss': 0.03782911243892852, 'loss': 0.04003091901540756}
# {'epoch': 93, 'iter': 30, 'avg_loss': 0.03788640866837194, 'loss': 0.03695536032319069}
# {'epoch': 93, 'iter': 40, 'avg_loss': 0.03821277345825986, 'loss': 0.038217250257730484}
# EP_train:93: 100% 46/46 [00:24<00:00,  1.89it/s]
# EP93, train_loss=0.03805, validate_loss=0.03171
# {'epoch': 94, 'iter': 0, 'avg_loss': 0.036744046956300735, 'loss': 0.036744046956300735}
# {'epoch': 94, 'iter': 10, 'avg_loss': 0.03769602829759771, 'loss': 0.039741333574056625}
# {'epoch': 94, 'iter': 20, 'avg_loss': 0.037559066499982564, 'loss': 0.037732381373643875}
# {'epoch': 94, 'iter': 30, 'avg_loss': 0.037955484443133874, 'loss': 0.04030831903219223}
# {'epoch': 94, 'iter': 40, 'avg_loss': 0.0379835777893299, 'loss': 0.040859729051589966}
# EP_train:94: 100% 46/46 [00:24<00:00,  1.87it/s]
# EP94, train_loss=0.03807, validate_loss=0.03075
# {'epoch': 95, 'iter': 0, 'avg_loss': 0.039183616638183594, 'loss': 0.039183616638183594}
# {'epoch': 95, 'iter': 10, 'avg_loss': 0.037518700415437874, 'loss': 0.04095207527279854}
# {'epoch': 95, 'iter': 20, 'avg_loss': 0.037706337514377776, 'loss': 0.037996839731931686}
# {'epoch': 95, 'iter': 30, 'avg_loss': 0.038064836854896235, 'loss': 0.03853211924433708}
# {'epoch': 95, 'iter': 40, 'avg_loss': 0.03804029851424985, 'loss': 0.03658515587449074}
# EP_train:95: 100% 46/46 [00:24<00:00,  1.89it/s]
# EP95, train_loss=0.03799, validate_loss=0.03181
# {'epoch': 96, 'iter': 0, 'avg_loss': 0.03874320164322853, 'loss': 0.03874320164322853}
# {'epoch': 96, 'iter': 10, 'avg_loss': 0.038219125094738876, 'loss': 0.038913555443286896}
# {'epoch': 96, 'iter': 20, 'avg_loss': 0.038090230630976815, 'loss': 0.038397207856178284}
# {'epoch': 96, 'iter': 30, 'avg_loss': 0.03793062353807111, 'loss': 0.03635800629854202}
# {'epoch': 96, 'iter': 40, 'avg_loss': 0.037930446881346586, 'loss': 0.03766718506813049}
# EP_train:96: 100% 46/46 [00:24<00:00,  1.89it/s]
# EP96, train_loss=0.03784, validate_loss=0.03095
# {'epoch': 97, 'iter': 0, 'avg_loss': 0.04165811464190483, 'loss': 0.04165811464190483}
# {'epoch': 97, 'iter': 10, 'avg_loss': 0.038021656599911774, 'loss': 0.03473984822630882}
# {'epoch': 97, 'iter': 20, 'avg_loss': 0.037617087009407225, 'loss': 0.036131929606199265}
# {'epoch': 97, 'iter': 30, 'avg_loss': 0.03774631431987209, 'loss': 0.03816579654812813}
# {'epoch': 97, 'iter': 40, 'avg_loss': 0.03766164201788786, 'loss': 0.039101190865039825}
# EP_train:97: 100% 46/46 [00:24<00:00,  1.88it/s]
# EP97, train_loss=0.03757, validate_loss=0.03106
# {'epoch': 98, 'iter': 0, 'avg_loss': 0.036645207554101944, 'loss': 0.036645207554101944}
# {'epoch': 98, 'iter': 10, 'avg_loss': 0.037333877249197525, 'loss': 0.036703627556562424}
# {'epoch': 98, 'iter': 20, 'avg_loss': 0.03755444820438113, 'loss': 0.037027012556791306}
# {'epoch': 98, 'iter': 30, 'avg_loss': 0.037405395940426855, 'loss': 0.03743385896086693}
# {'epoch': 98, 'iter': 40, 'avg_loss': 0.037318029054781286, 'loss': 0.036681074649095535}
# EP_train:98: 100% 46/46 [00:23<00:00,  1.92it/s]
# EP98, train_loss=0.03734, validate_loss=0.02984
# EP:98 Model Saved on: /content/drive/MyDrive/checkpoints/pretraincheckpoint.tar
# {'epoch': 99, 'iter': 0, 'avg_loss': 0.03622923046350479, 'loss': 0.03622923046350479}
# {'epoch': 99, 'iter': 10, 'avg_loss': 0.03732356225902384, 'loss': 0.03636176511645317}
# {'epoch': 99, 'iter': 20, 'avg_loss': 0.03741790194596563, 'loss': 0.03867808356881142}
# {'epoch': 99, 'iter': 30, 'avg_loss': 0.03744881239629561, 'loss': 0.035791922360658646}
# {'epoch': 99, 'iter': 40, 'avg_loss': 0.03738570413211497, 'loss': 0.036043353378772736}
# EP_train:99: 100% 46/46 [00:24<00:00,  1.88it/s]
# EP99, train_loss=0.03728, validate_loss=0.02986

# %% [markdown]
# # Fine-Tuning

# %%
# !python /content/SITS-BERT/code/finetuning.py \
    --file_path '/content/drive/MyDrive/California-Labeled/California-Labeled/' \
    --pretrain_path '/content/drive/MyDrive/checkpoints/pretrain/' \
    --finetune_path '/content/drive/MyDrive/checkpoints/finetune/' \
    --max_length 64 \
    --num_features 10 \
    --num_classes 13 \
    --epochs 100\
    --batch_size 128 \
    --hidden_size 256 \
    --layers 3 \
    --attn_heads 8 \
    --learning_rate 2e-4 \
    --dropout 0.1
# Out:
# 2025-05-18 10:19:00.108137: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747563540.129705   14020 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747563540.135900   14020 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-18 10:19:00.164424: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading Data sets...
# training samples: 1300, validation samples: 1300, testing samples: 318588
# Creating Dataloader...
# Initialing SITS-BERT...
# Loading pre-trained model parameters...
# Creating Downstream Task Trainer...
# Fine-tuning SITS-BERT...
# EP0, train_OA=9.46, train_Kappa=0.019, validate_OA=23.62, validate_Kappa=0.172
# EP:0 Model Saved on: /content/drive/MyDrive/checkpoints/finetune/checkpoint.tar
# EP1, train_OA=25.69, train_Kappa=0.195, validate_OA=32.54, validate_Kappa=0.269
# EP:1 Model Saved on: /content/drive/MyDrive/checkpoints/finetune/checkpoint.tar
# EP2, train_OA=37.23, train_Kappa=0.320, validate_OA=38.23, validate_Kappa=0.331
# EP:2 Model Saved on: /content/drive/MyDrive/checkpoints/finetune/checkpoint.tar
# EP3, train_OA=48.85, train_Kappa=0.446, validate_OA=44.54, validate_Kappa=0.399
# EP:3 Model Saved on: /content/drive/MyDrive/checkpoints/finetune/checkpoint.tar
# EP4, train_OA=56.69, train_Kappa=0.531, validate_OA=53.54, validate_Kappa=0.497
# EP:4 Model Saved on: /content/drive/MyDrive/checkpoints/finetune/checkpoint.tar
# EP5, train_OA=65.85, train_Kappa=0.630, validate_OA=62.46, validate_Kappa=0.593
# EP:5 Model Saved on: /content/drive/MyDrive/checkpoints/finetune/checkpoint.tar
# EP6, train_OA=70.92, train_Kappa=0.685, validate_OA=69.54, validate_Kappa=0.670
# EP:6 Model Saved on: /content/drive/MyDrive/checkpoints/finetune/checkpoint.tar
# EP7, train_OA=74.00, train_Kappa=0.718, validate_OA=70.08, validate_Kappa=0.676
# EP:7 Model Saved on: /content/drive/MyDrive/checkpoints/finetune/checkpoint.tar
# EP8, train_OA=75.23, train_Kappa=0.732, validate_OA=74.08, validate_Kappa=0.719
# EP:8 Model Saved on: /content/drive/MyDrive/checkpoints/finetune/checkpoint.tar
# EP9, train_OA=77.38, train_Kappa=0.755, validate_OA=77.54, validate_Kappa=0.757
# EP:9 Model Saved on: /content/drive/MyDrive/checkpoints/finetune/checkpoint.tar
# EP10, train_OA=79.38, train_Kappa=0.777, validate_OA=78.69, validate_Kappa=0.769
# EP:10 Model Saved on: /content/drive/MyDrive/checkpoints/finetune/checkpoint.tar
# EP11, train_OA=81.15, train_Kappa=0.796, validate_OA=79.08, validate_Kappa=0.773
# EP:11 Model Saved on: /content/drive/MyDrive/checkpoints/finetune/checkpoint.tar
# EP12, train_OA=81.00, train_Kappa=0.794, validate_OA=79.62, validate_Kappa=0.779
# EP:12 Model Saved on: /content/drive/MyDrive/checkpoints/finetune/checkpoint.tar
# EP13, train_OA=84.00, train_Kappa=0.827, validate_OA=81.62, validate_Kappa=0.801
# EP:13 Model Saved on: /content/drive/MyDrive/checkpoints/finetune/checkpoint.tar
# EP14, train_OA=85.23, train_Kappa=0.840, validate_OA=82.31, validate_Kappa=0.808
# EP:14 Model Saved on: /content/drive/MyDrive/checkpoints/finetune/checkpoint.tar
# EP15, train_OA=86.23, train_Kappa=0.851, validate_OA=82.92, validate_Kappa=0.815
# EP:15 Model Saved on: /content/drive/MyDrive/checkpoints/finetune/checkpoint.tar
# EP16, train_OA=86.77, train_Kappa=0.857, validate_OA=84.00, validate_Kappa=0.827
# EP:16 Model Saved on: /content/drive/MyDrive/checkpoints/finetune/checkpoint.tar
# EP17, train_OA=87.00, train_Kappa=0.859, validate_OA=85.00, validate_Kappa=0.837
# EP:17 Model Saved on: /content/drive/MyDrive/checkpoints/finetune/checkpoint.tar
# EP18, train_OA=88.00, train_Kappa=0.870, validate_OA=84.62, validate_Kappa=0.833
# EP19, train_OA=88.08, train_Kappa=0.871, validate_OA=86.15, validate_Kappa=0.850
# EP:19 Model Saved on: /content/drive/MyDrive/checkpoints/finetune/checkpoint.tar
# EP20, train_OA=90.15, train_Kappa=0.893, validate_OA=83.92, validate_Kappa=0.826
# EP21, train_OA=89.62, train_Kappa=0.887, validate_OA=86.54, validate_Kappa=0.854
# EP:21 Model Saved on: /content/drive/MyDrive/checkpoints/finetune/checkpoint.tar
# EP22, train_OA=90.38, train_Kappa=0.896, validate_OA=86.38, validate_Kappa=0.852
# EP23, train_OA=89.54, train_Kappa=0.887, validate_OA=85.85, validate_Kappa=0.847
# EP24, train_OA=91.15, train_Kappa=0.904, validate_OA=87.38, validate_Kappa=0.863
# EP:24 Model Saved on: /content/drive/MyDrive/checkpoints/finetune/checkpoint.tar
# EP25, train_OA=91.15, train_Kappa=0.904, validate_OA=88.00, validate_Kappa=0.870
# EP:25 Model Saved on: /content/drive/MyDrive/checkpoints/finetune/checkpoint.tar
# EP26, train_OA=90.00, train_Kappa=0.892, validate_OA=87.08, validate_Kappa=0.860
# EP27, train_OA=91.77, train_Kappa=0.911, validate_OA=85.38, validate_Kappa=0.842
# EP28, train_OA=91.38, train_Kappa=0.907, validate_OA=88.23, validate_Kappa=0.872
# EP:28 Model Saved on: /content/drive/MyDrive/checkpoints/finetune/checkpoint.tar
# EP29, train_OA=91.92, train_Kappa=0.912, validate_OA=87.08, validate_Kappa=0.860
# EP30, train_OA=91.38, train_Kappa=0.907, validate_OA=87.62, validate_Kappa=0.866
# EP31, train_OA=91.31, train_Kappa=0.906, validate_OA=87.23, validate_Kappa=0.862
# EP32, train_OA=91.77, train_Kappa=0.911, validate_OA=85.69, validate_Kappa=0.845
# EP33, train_OA=91.92, train_Kappa=0.912, validate_OA=86.69, validate_Kappa=0.856
# EP34, train_OA=92.23, train_Kappa=0.916, validate_OA=88.92, validate_Kappa=0.880
# EP:34 Model Saved on: /content/drive/MyDrive/checkpoints/finetune/checkpoint.tar
# EP35, train_OA=92.69, train_Kappa=0.921, validate_OA=89.31, validate_Kappa=0.884
# EP:35 Model Saved on: /content/drive/MyDrive/checkpoints/finetune/checkpoint.tar
# EP36, train_OA=93.23, train_Kappa=0.927, validate_OA=88.92, validate_Kappa=0.880
# EP37, train_OA=92.54, train_Kappa=0.919, validate_OA=88.69, validate_Kappa=0.878
# EP38, train_OA=92.92, train_Kappa=0.923, validate_OA=89.54, validate_Kappa=0.887
# EP:38 Model Saved on: /content/drive/MyDrive/checkpoints/finetune/checkpoint.tar
# EP39, train_OA=93.62, train_Kappa=0.931, validate_OA=86.31, validate_Kappa=0.852
# EP40, train_OA=92.23, train_Kappa=0.916, validate_OA=88.77, validate_Kappa=0.878
# EP41, train_OA=94.23, train_Kappa=0.938, validate_OA=89.15, validate_Kappa=0.882
# EP42, train_OA=93.46, train_Kappa=0.929, validate_OA=88.62, validate_Kappa=0.877
# EP43, train_OA=94.85, train_Kappa=0.944, validate_OA=89.38, validate_Kappa=0.885
# EP44, train_OA=93.69, train_Kappa=0.932, validate_OA=89.85, validate_Kappa=0.890
# EP:44 Model Saved on: /content/drive/MyDrive/checkpoints/finetune/checkpoint.tar
# EP45, train_OA=93.38, train_Kappa=0.928, validate_OA=89.46, validate_Kappa=0.886
# EP46, train_OA=94.46, train_Kappa=0.940, validate_OA=89.00, validate_Kappa=0.881
# EP47, train_OA=94.31, train_Kappa=0.938, validate_OA=88.92, validate_Kappa=0.880
# EP48, train_OA=93.85, train_Kappa=0.933, validate_OA=88.69, validate_Kappa=0.878
# EP49, train_OA=94.08, train_Kappa=0.936, validate_OA=88.92, validate_Kappa=0.880
# EP50, train_OA=93.77, train_Kappa=0.932, validate_OA=88.54, validate_Kappa=0.876
# EP51, train_OA=94.38, train_Kappa=0.939, validate_OA=89.31, validate_Kappa=0.884
# EP52, train_OA=92.92, train_Kappa=0.923, validate_OA=90.15, validate_Kappa=0.893
# EP:52 Model Saved on: /content/drive/MyDrive/checkpoints/finetune/checkpoint.tar
# EP53, train_OA=93.54, train_Kappa=0.930, validate_OA=90.31, validate_Kappa=0.895
# EP:53 Model Saved on: /content/drive/MyDrive/checkpoints/finetune/checkpoint.tar
# EP54, train_OA=94.00, train_Kappa=0.935, validate_OA=89.62, validate_Kappa=0.887
# EP55, train_OA=95.62, train_Kappa=0.953, validate_OA=89.69, validate_Kappa=0.888
# EP56, train_OA=95.69, train_Kappa=0.953, validate_OA=89.92, validate_Kappa=0.891
# EP57, train_OA=95.08, train_Kappa=0.947, validate_OA=90.23, validate_Kappa=0.894
# EP58, train_OA=95.38, train_Kappa=0.950, validate_OA=90.38, validate_Kappa=0.896
# EP:58 Model Saved on: /content/drive/MyDrive/checkpoints/finetune/checkpoint.tar
# EP59, train_OA=96.38, train_Kappa=0.961, validate_OA=91.00, validate_Kappa=0.902
# EP:59 Model Saved on: /content/drive/MyDrive/checkpoints/finetune/checkpoint.tar
# EP60, train_OA=95.62, train_Kappa=0.953, validate_OA=88.69, validate_Kappa=0.878
# EP61, train_OA=95.00, train_Kappa=0.946, validate_OA=89.69, validate_Kappa=0.888
# EP62, train_OA=94.38, train_Kappa=0.939, validate_OA=90.54, validate_Kappa=0.897
# EP63, train_OA=96.85, train_Kappa=0.966, validate_OA=89.31, validate_Kappa=0.884
# EP64, train_OA=95.38, train_Kappa=0.950, validate_OA=90.15, validate_Kappa=0.893
# EP65, train_OA=95.62, train_Kappa=0.953, validate_OA=89.54, validate_Kappa=0.887
# EP66, train_OA=95.69, train_Kappa=0.953, validate_OA=90.92, validate_Kappa=0.902
# EP67, train_OA=95.54, train_Kappa=0.952, validate_OA=90.46, validate_Kappa=0.897
# EP68, train_OA=94.31, train_Kappa=0.938, validate_OA=90.62, validate_Kappa=0.898
# EP69, train_OA=95.77, train_Kappa=0.954, validate_OA=91.15, validate_Kappa=0.904
# EP:69 Model Saved on: /content/drive/MyDrive/checkpoints/finetune/checkpoint.tar
# EP70, train_OA=95.85, train_Kappa=0.955, validate_OA=90.15, validate_Kappa=0.893
# EP71, train_OA=96.38, train_Kappa=0.961, validate_OA=89.92, validate_Kappa=0.891
# EP72, train_OA=96.00, train_Kappa=0.957, validate_OA=89.31, validate_Kappa=0.884
# EP73, train_OA=96.38, train_Kappa=0.961, validate_OA=90.54, validate_Kappa=0.897
# EP74, train_OA=95.69, train_Kappa=0.953, validate_OA=89.38, validate_Kappa=0.885
# EP75, train_OA=96.31, train_Kappa=0.960, validate_OA=90.38, validate_Kappa=0.896
# EP76, train_OA=95.62, train_Kappa=0.953, validate_OA=89.00, validate_Kappa=0.881
# EP77, train_OA=96.31, train_Kappa=0.960, validate_OA=90.15, validate_Kappa=0.893
# EP78, train_OA=97.54, train_Kappa=0.973, validate_OA=90.62, validate_Kappa=0.898
# EP79, train_OA=96.69, train_Kappa=0.964, validate_OA=89.92, validate_Kappa=0.891
# EP80, train_OA=96.08, train_Kappa=0.958, validate_OA=91.15, validate_Kappa=0.904
# EP81, train_OA=95.92, train_Kappa=0.956, validate_OA=90.54, validate_Kappa=0.897
# EP82, train_OA=95.31, train_Kappa=0.949, validate_OA=90.46, validate_Kappa=0.897
# EP83, train_OA=96.69, train_Kappa=0.964, validate_OA=90.92, validate_Kappa=0.902
# EP84, train_OA=97.08, train_Kappa=0.968, validate_OA=90.62, validate_Kappa=0.898
# EP85, train_OA=96.85, train_Kappa=0.966, validate_OA=89.85, validate_Kappa=0.890
# EP86, train_OA=96.38, train_Kappa=0.961, validate_OA=90.38, validate_Kappa=0.896
# EP87, train_OA=96.54, train_Kappa=0.962, validate_OA=90.85, validate_Kappa=0.901
# EP88, train_OA=96.92, train_Kappa=0.967, validate_OA=91.00, validate_Kappa=0.902
# EP89, train_OA=97.15, train_Kappa=0.969, validate_OA=90.92, validate_Kappa=0.902
# EP90, train_OA=97.00, train_Kappa=0.968, validate_OA=90.77, validate_Kappa=0.900
# EP91, train_OA=97.38, train_Kappa=0.972, validate_OA=89.69, validate_Kappa=0.888
# EP92, train_OA=97.15, train_Kappa=0.969, validate_OA=91.15, validate_Kappa=0.904
# EP93, train_OA=96.92, train_Kappa=0.967, validate_OA=90.23, validate_Kappa=0.894
# EP94, train_OA=96.85, train_Kappa=0.966, validate_OA=90.46, validate_Kappa=0.897
# EP95, train_OA=97.62, train_Kappa=0.974, validate_OA=90.38, validate_Kappa=0.896
# EP96, train_OA=97.08, train_Kappa=0.968, validate_OA=90.46, validate_Kappa=0.897
# EP97, train_OA=96.92, train_Kappa=0.967, validate_OA=90.62, validate_Kappa=0.898
# EP98, train_OA=97.23, train_Kappa=0.970, validate_OA=91.38, validate_Kappa=0.907
# EP:98 Model Saved on: /content/drive/MyDrive/checkpoints/finetune/checkpoint.tar
# EP99, train_OA=97.69, train_Kappa=0.975, validate_OA=91.46, validate_Kappa=0.907
# EP:99 Model Saved on: /content/drive/MyDrive/checkpoints/finetune/checkpoint.tar
#
#
#
#
# Testing SITS-BERT...
# EP:99 Model loaded from: /content/drive/MyDrive/checkpoints/finetune/checkpoint.tar
# test_OA = 90.79, test_kappa = 0.892, test_AA = 0.912

# %% [markdown]
# # Fine-Tuning With LoRA

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import math

class LoRALinear(nn.Module):
    def __init__(self, in_features, out_features, r=4, alpha=16, dropout=0.1):
        super().__init__()
        self.r = r
        self.alpha = alpha
        self.dropout = nn.Dropout(dropout)
        self.scaling = alpha / r

        self.weight = nn.Parameter(torch.empty(out_features, in_features))
        nn.init.kaiming_uniform_(self.weight, a=math.sqrt(5))
        self.weight.requires_grad = False  # Freeze base weights

        self.lora_A = nn.Parameter(torch.randn(r, in_features) * 0.01)
        self.lora_B = nn.Parameter(torch.randn(out_features, r) * 0.01)

    def forward(self, x):
        base = F.linear(x, self.weight)
        lora = self.dropout(x) @ self.lora_A.T @ self.lora_B.T * self.scaling
        return base + lora

# %%
import sys
sys.path.append('/content/SITS-BERT/code')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import math
import sys
sys.path.append('/content/SITS-BERT/code')

# LoRALinear definition (directly here)
class LoRALinear(nn.Module):
    def __init__(self, in_features, out_features, r=4, alpha=16, dropout=0.1):
        super().__init__()
        self.r = r
        self.alpha = alpha
        self.dropout = nn.Dropout(dropout)
        self.scaling = alpha / r

        self.weight = nn.Parameter(torch.empty(out_features, in_features))
        nn.init.kaiming_uniform_(self.weight, a=math.sqrt(5))
        self.weight.requires_grad = False  # Freeze base weights

        self.lora_A = nn.Parameter(torch.randn(r, in_features) * 0.01)
        self.lora_B = nn.Parameter(torch.randn(out_features, r) * 0.01)

    def forward(self, x):
        base = F.linear(x, self.weight)
        lora = self.dropout(x) @ self.lora_A.T @ self.lora_B.T * self.scaling
        return base + lora


from model.attention.multi_head import MultiHeadedAttention
from model.attention.single import Attention


def patch_attention_with_lora():
    def modified_init(self, h, d_model, dropout=0.1):
        super(MultiHeadedAttention, self).__init__()
        assert d_model % h == 0
        self.d_k = d_model // h
        self.h = h

        self.linear_q = LoRALinear(d_model, d_model, r=4, alpha=16, dropout=dropout)
        self.linear_k = nn.Linear(d_model, d_model)
        self.linear_v = LoRALinear(d_model, d_model, r=4, alpha=16, dropout=dropout)
        self.output_linear = nn.Linear(d_model, d_model)

        self.attention = Attention()
        self.dropout = nn.Dropout(p=dropout)

    def modified_forward(self, query, key, value, mask=None):
        batch_size = query.size(0)

        query = self.linear_q(query).view(batch_size, -1, self.h, self.d_k).transpose(1, 2)
        key   = self.linear_k(key).view(batch_size, -1, self.h, self.d_k).transpose(1, 2)
        value = self.linear_v(value).view(batch_size, -1, self.h, self.d_k).transpose(1, 2)

        x, attn = self.attention(query, key, value, mask=mask, dropout=self.dropout)
        x = x.transpose(1, 2).contiguous().view(batch_size, -1, self.h * self.d_k)
        return self.output_linear(x)

    MultiHeadedAttention.__init__ = modified_init
    MultiHeadedAttention.forward = modified_forward


patch_attention_with_lora()
print("✅ MultiHeadedAttention patched with LoRA.")

# %%
from model.bert import SBERT

model = SBERT(
    num_features=10,
    hidden=256,
    n_layers=3,
    attn_heads=8,
    dropout=0.1
)

# %%
def count_lora_parameters(model):
    total = 0
    for name, param in model.named_parameters():
        if 'lora_' in name and param.requires_grad:
            print(f"{name}: {param.numel()} parameters")
            total += param.numel()
    print(f"\n🔢 Total trainable LoRA parameters: {total}")
    return total

# %%
def count_total_parameters(model):
    return sum(p.numel() for p in model.parameters())

def count_trainable_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f"🧠 Total parameters: {count_total_parameters(model)}")
print(f"🎯 Trainable parameters: {count_trainable_parameters(model)}")
print(f"📦 LoRA-only trainable parameters:")
count_lora_parameters(model)

# %%
# Freeze everything
for param in model.parameters():
    param.requires_grad = False

# Unfreeze LoRA layers only
for name, param in model.named_parameters():
    if 'lora' in name.lower():
        param.requires_grad = True
        print(f"✅ Unfrozen: {name}")

# %%
# !python /content/SITS-BERT/code/finetuning.py \
    --file_path '/content/drive/MyDrive/California-Labeled/California-Labeled/' \
    --pretrain_path '/content/drive/MyDrive/checkpoints/pretrain/' \
    --finetune_path '/content/drive/MyDrive/checkpoints/finetune/' \
    --max_length 64 \
    --num_features 10 \
    --num_classes 13 \
    --epochs 100 \
    --batch_size 128 \
    --hidden_size 256 \
    --layers 3 \
    --attn_heads 8 \
    --learning_rate 2e-4 \
    --dropout 0.1
