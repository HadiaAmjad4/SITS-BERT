# %% [markdown]
# # **WORKING LoRA SCRIPT **

# %%
# !pip install peft transformers accelerate
# Out:
# Requirement already satisfied: peft in /usr/local/lib/python3.11/dist-packages (0.15.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.51.3)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.6.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from peft) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from peft) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from peft) (6.0.2)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from peft) (2.6.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from peft) (4.67.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from peft) (0.5.3)
# Requirement already satisfied: huggingface_hub>=0.25.0 in /usr/local/lib/python3.11/dist-packages (from peft) (0.31.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.25.0->peft) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.25.0->peft) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.13.0->peft)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.13.0->peft)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.13.0->peft)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.13.0->peft)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.13.0->peft)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.13.0->peft)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.13.0->peft)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.13.0->peft)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.13.0->peft)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.13.0->peft)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.13.0->peft) (3.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 96.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 82.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 60.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.3 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.0 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 103.3 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/linlei1214/SITS-BERT.git
# Out:
# Cloning into 'SITS-BERT'...
# remote: Enumerating objects: 153, done.
# remote: Counting objects: 100% (153/153), done.
# remote: Compressing objects: 100% (137/137), done.
# remote: Total 153 (delta 24), reused 118 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (153/153), 8.70 MiB | 37.29 MiB/s, done.
# Resolving deltas: 100% (24/24), done.

# %% [markdown]
# # LoRA

# %%
# !python /content/SITS-BERT/code/finetuning_lora.py \
    --file_path '/content/drive/MyDrive/California-Labeled/California-Labeled/' \
    --pretrain_path '/content/SITS-BERT/checkpoints/pretrain/' \
    --finetune_path '/content/drive/MyDrive/checkpoints/finetune_LoRA/california' \
    --max_length 64 \
    --num_features 10 \
    --num_classes 13 \
    --epochs 100 \
    --batch_size 128 \
    --hidden_size 256 \
    --layers 3 \
    --attn_heads 8 \
    --learning_rate 1e-4 \
    --dropout 0.1 \
    --use_lora \
    --lora_rank 16 \
    --lora_alpha 24 \
    --lora_dropout 0.01
# Out:
# 2025-05-19 11:41:58.602560: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747654918.622965    4845 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747654918.629143    4845 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-19 11:41:58.649394: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ✅ LoRA enabled with rank=16, alpha=24, dropout=0.01
# Loading Data sets...
# training samples: 1300, validation samples: 1300, testing samples: 318588
# Creating Dataloader...
# Initializing SITS-BERT...
# Loading pre-trained model parameters...
# ✅ Pretrained weights loaded (excluding LoRA params)
# 🧠 Total parameters: 2418304
# 🎯 Trainable parameters: 49152
# Creating Downstream Task Trainer...
# Fine-tuning SITS-BERT...
# EP0, train_OA=6.69, train_Kappa=-0.011, validate_OA=5.85, validate_Kappa=-0.020
# EP:0 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP1, train_OA=4.92, train_Kappa=-0.030, validate_OA=6.85, validate_Kappa=-0.009
# EP:1 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP2, train_OA=6.08, train_Kappa=-0.018, validate_OA=10.46, validate_Kappa=0.030
# EP:2 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP3, train_OA=8.31, train_Kappa=0.007, validate_OA=13.38, validate_Kappa=0.062
# EP:3 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP4, train_OA=9.54, train_Kappa=0.020, validate_OA=15.08, validate_Kappa=0.080
# EP:4 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP5, train_OA=12.31, train_Kappa=0.050, validate_OA=17.85, validate_Kappa=0.110
# EP:5 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP6, train_OA=14.46, train_Kappa=0.073, validate_OA=20.08, validate_Kappa=0.134
# EP:6 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP7, train_OA=18.54, train_Kappa=0.118, validate_OA=21.23, validate_Kappa=0.147
# EP:7 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP8, train_OA=20.08, train_Kappa=0.134, validate_OA=22.92, validate_Kappa=0.165
# EP:8 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP9, train_OA=19.38, train_Kappa=0.127, validate_OA=25.00, validate_Kappa=0.187
# EP:9 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP10, train_OA=25.08, train_Kappa=0.188, validate_OA=27.92, validate_Kappa=0.219
# EP:10 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP11, train_OA=27.46, train_Kappa=0.214, validate_OA=30.15, validate_Kappa=0.243
# EP:11 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP12, train_OA=29.15, train_Kappa=0.232, validate_OA=32.92, validate_Kappa=0.273
# EP:12 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP13, train_OA=32.00, train_Kappa=0.263, validate_OA=34.00, validate_Kappa=0.285
# EP:13 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP14, train_OA=34.31, train_Kappa=0.288, validate_OA=35.08, validate_Kappa=0.297
# EP:14 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP15, train_OA=36.69, train_Kappa=0.314, validate_OA=37.69, validate_Kappa=0.325
# EP:15 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP16, train_OA=38.00, train_Kappa=0.328, validate_OA=39.23, validate_Kappa=0.342
# EP:16 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP17, train_OA=39.62, train_Kappa=0.346, validate_OA=40.15, validate_Kappa=0.352
# EP:17 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP18, train_OA=43.15, train_Kappa=0.384, validate_OA=40.00, validate_Kappa=0.350
# EP19, train_OA=45.00, train_Kappa=0.404, validate_OA=44.69, validate_Kappa=0.401
# EP:19 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP20, train_OA=47.92, train_Kappa=0.436, validate_OA=46.46, validate_Kappa=0.420
# EP:20 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP21, train_OA=46.08, train_Kappa=0.416, validate_OA=46.54, validate_Kappa=0.421
# EP:21 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP22, train_OA=51.38, train_Kappa=0.473, validate_OA=48.62, validate_Kappa=0.443
# EP:22 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP23, train_OA=50.31, train_Kappa=0.462, validate_OA=50.23, validate_Kappa=0.461
# EP:23 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP24, train_OA=52.15, train_Kappa=0.482, validate_OA=52.54, validate_Kappa=0.486
# EP:24 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP25, train_OA=56.54, train_Kappa=0.529, validate_OA=53.08, validate_Kappa=0.492
# EP:25 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP26, train_OA=55.31, train_Kappa=0.516, validate_OA=53.38, validate_Kappa=0.495
# EP:26 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP27, train_OA=56.62, train_Kappa=0.530, validate_OA=53.62, validate_Kappa=0.497
# EP:27 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP28, train_OA=58.15, train_Kappa=0.547, validate_OA=55.15, validate_Kappa=0.514
# EP:28 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP29, train_OA=59.38, train_Kappa=0.560, validate_OA=55.77, validate_Kappa=0.521
# EP:29 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP30, train_OA=61.85, train_Kappa=0.587, validate_OA=56.54, validate_Kappa=0.529
# EP:30 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP31, train_OA=61.77, train_Kappa=0.586, validate_OA=57.46, validate_Kappa=0.539
# EP:31 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP32, train_OA=62.46, train_Kappa=0.593, validate_OA=57.92, validate_Kappa=0.544
# EP:32 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP33, train_OA=62.38, train_Kappa=0.592, validate_OA=59.77, validate_Kappa=0.564
# EP:33 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP34, train_OA=64.31, train_Kappa=0.613, validate_OA=59.46, validate_Kappa=0.561
# EP35, train_OA=64.15, train_Kappa=0.612, validate_OA=58.77, validate_Kappa=0.553
# EP36, train_OA=65.69, train_Kappa=0.628, validate_OA=60.38, validate_Kappa=0.571
# EP:36 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP37, train_OA=67.54, train_Kappa=0.648, validate_OA=61.00, validate_Kappa=0.577
# EP:37 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP38, train_OA=66.23, train_Kappa=0.634, validate_OA=60.23, validate_Kappa=0.569
# EP39, train_OA=66.31, train_Kappa=0.635, validate_OA=60.62, validate_Kappa=0.573
# EP40, train_OA=66.85, train_Kappa=0.641, validate_OA=61.46, validate_Kappa=0.583
# EP:40 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP41, train_OA=67.15, train_Kappa=0.644, validate_OA=62.23, validate_Kappa=0.591
# EP:41 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP42, train_OA=68.23, train_Kappa=0.656, validate_OA=61.62, validate_Kappa=0.584
# EP43, train_OA=68.77, train_Kappa=0.662, validate_OA=61.38, validate_Kappa=0.582
# EP44, train_OA=69.69, train_Kappa=0.672, validate_OA=62.15, validate_Kappa=0.590
# EP45, train_OA=70.77, train_Kappa=0.683, validate_OA=63.31, validate_Kappa=0.603
# EP:45 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP46, train_OA=69.62, train_Kappa=0.671, validate_OA=63.46, validate_Kappa=0.604
# EP:46 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP47, train_OA=70.54, train_Kappa=0.681, validate_OA=62.38, validate_Kappa=0.592
# EP48, train_OA=70.62, train_Kappa=0.682, validate_OA=62.08, validate_Kappa=0.589
# EP49, train_OA=71.77, train_Kappa=0.694, validate_OA=62.54, validate_Kappa=0.594
# EP50, train_OA=71.92, train_Kappa=0.696, validate_OA=64.62, validate_Kappa=0.617
# EP:50 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP51, train_OA=73.31, train_Kappa=0.711, validate_OA=63.85, validate_Kappa=0.608
# EP52, train_OA=72.31, train_Kappa=0.700, validate_OA=62.31, validate_Kappa=0.592
# EP53, train_OA=72.31, train_Kappa=0.700, validate_OA=63.38, validate_Kappa=0.603
# EP54, train_OA=73.08, train_Kappa=0.708, validate_OA=63.62, validate_Kappa=0.606
# EP55, train_OA=73.08, train_Kappa=0.708, validate_OA=64.15, validate_Kappa=0.612
# EP56, train_OA=73.46, train_Kappa=0.713, validate_OA=64.31, validate_Kappa=0.613
# EP57, train_OA=74.46, train_Kappa=0.723, validate_OA=64.15, validate_Kappa=0.612
# EP58, train_OA=74.23, train_Kappa=0.721, validate_OA=64.85, validate_Kappa=0.619
# EP:58 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP59, train_OA=76.00, train_Kappa=0.740, validate_OA=65.62, validate_Kappa=0.627
# EP:59 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP60, train_OA=75.77, train_Kappa=0.737, validate_OA=65.00, validate_Kappa=0.621
# EP61, train_OA=75.38, train_Kappa=0.733, validate_OA=64.46, validate_Kappa=0.615
# EP62, train_OA=75.62, train_Kappa=0.736, validate_OA=64.69, validate_Kappa=0.618
# EP63, train_OA=77.38, train_Kappa=0.755, validate_OA=65.46, validate_Kappa=0.626
# EP64, train_OA=76.15, train_Kappa=0.742, validate_OA=65.92, validate_Kappa=0.631
# EP:64 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP65, train_OA=75.92, train_Kappa=0.739, validate_OA=66.54, validate_Kappa=0.637
# EP:65 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP66, train_OA=75.62, train_Kappa=0.736, validate_OA=66.62, validate_Kappa=0.638
# EP:66 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP67, train_OA=77.62, train_Kappa=0.758, validate_OA=66.77, validate_Kappa=0.640
# EP:67 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP68, train_OA=76.38, train_Kappa=0.744, validate_OA=66.62, validate_Kappa=0.638
# EP69, train_OA=77.85, train_Kappa=0.760, validate_OA=66.23, validate_Kappa=0.634
# EP70, train_OA=78.85, train_Kappa=0.771, validate_OA=66.23, validate_Kappa=0.634
# EP71, train_OA=77.69, train_Kappa=0.758, validate_OA=66.69, validate_Kappa=0.639
# EP72, train_OA=79.23, train_Kappa=0.775, validate_OA=67.23, validate_Kappa=0.645
# EP:72 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP73, train_OA=79.77, train_Kappa=0.781, validate_OA=67.08, validate_Kappa=0.643
# EP74, train_OA=79.15, train_Kappa=0.774, validate_OA=67.38, validate_Kappa=0.647
# EP:74 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP75, train_OA=80.23, train_Kappa=0.786, validate_OA=67.77, validate_Kappa=0.651
# EP:75 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP76, train_OA=79.77, train_Kappa=0.781, validate_OA=67.46, validate_Kappa=0.648
# EP77, train_OA=80.46, train_Kappa=0.788, validate_OA=67.54, validate_Kappa=0.648
# EP78, train_OA=80.23, train_Kappa=0.786, validate_OA=67.77, validate_Kappa=0.651
# EP79, train_OA=81.38, train_Kappa=0.798, validate_OA=67.77, validate_Kappa=0.651
# EP80, train_OA=81.00, train_Kappa=0.794, validate_OA=68.08, validate_Kappa=0.654
# EP:80 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP81, train_OA=80.46, train_Kappa=0.788, validate_OA=68.00, validate_Kappa=0.653
# EP82, train_OA=80.69, train_Kappa=0.791, validate_OA=68.69, validate_Kappa=0.661
# EP:82 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP83, train_OA=81.15, train_Kappa=0.796, validate_OA=68.46, validate_Kappa=0.658
# EP84, train_OA=82.08, train_Kappa=0.806, validate_OA=68.15, validate_Kappa=0.655
# EP85, train_OA=82.08, train_Kappa=0.806, validate_OA=68.69, validate_Kappa=0.661
# EP86, train_OA=82.85, train_Kappa=0.814, validate_OA=69.62, validate_Kappa=0.671
# EP:86 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP87, train_OA=82.31, train_Kappa=0.808, validate_OA=70.00, validate_Kappa=0.675
# EP:87 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP88, train_OA=82.31, train_Kappa=0.808, validate_OA=70.00, validate_Kappa=0.675
# EP89, train_OA=83.46, train_Kappa=0.821, validate_OA=70.15, validate_Kappa=0.677
# EP:89 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP90, train_OA=82.69, train_Kappa=0.812, validate_OA=70.23, validate_Kappa=0.677
# EP:90 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP91, train_OA=82.85, train_Kappa=0.814, validate_OA=70.08, validate_Kappa=0.676
# EP92, train_OA=84.00, train_Kappa=0.827, validate_OA=70.54, validate_Kappa=0.681
# EP:92 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP93, train_OA=83.54, train_Kappa=0.822, validate_OA=70.54, validate_Kappa=0.681
# EP94, train_OA=83.92, train_Kappa=0.826, validate_OA=70.23, validate_Kappa=0.677
# EP95, train_OA=83.92, train_Kappa=0.826, validate_OA=71.00, validate_Kappa=0.686
# EP:95 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP96, train_OA=84.38, train_Kappa=0.831, validate_OA=71.38, validate_Kappa=0.690
# EP:96 Model Saved on: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# EP97, train_OA=84.08, train_Kappa=0.827, validate_OA=71.23, validate_Kappa=0.688
# EP98, train_OA=84.54, train_Kappa=0.833, validate_OA=71.38, validate_Kappa=0.690
# EP99, train_OA=85.77, train_Kappa=0.846, validate_OA=71.08, validate_Kappa=0.687
#
#
#
#
# Testing SITS-BERT...
# EP:96 Model loaded from: /content/drive/MyDrive/checkpoints/finetune_LoRA/californiacheckpoint.tar
# test_OA = 79.71, test_kappa = 0.762, test_AA = 0.725
